# %%
# %run ../run_v4_period_results.py
# Out:
# ...
# NGC 1333:
# Per nir 50 +/- 1 sigma: 2.3 +3.4 -0.9
# Per IR 50 +/- 1 sigma: 3.5 +2.2 -1.3
# --
# Amp nir 50 +/- 1 sigma: 1.1e-02 +9.9e-03 -4.4e-03
# Amp IR 50 +/- 1 sigma: 3.3e-02 +5.1e-02 -2.1e-02
# Log Per bins:  -0.11314264643119235 1.744725685332582
# Log amp bins:  -2.3159896476462887 -0.6408834417764375
# 0 3
# 0 3
# 3 6
# 3 6
# 6 9.05
# 6 9.05
# 0 3
# 0 3
# 3 6
# 3 6
# 6 9.05
# 6 9.05
# ...
# IC 348:
# Per nir 50 +/- 1 sigma: 3.3 +5.4 -2.2
# Per IR 50 +/- 1 sigma: 3.2 +4.0 -1.1
# --
# Amp nir 50 +/- 1 sigma: 1.7e-02 +1.8e-02 -5.7e-03
# Amp IR 50 +/- 1 sigma: 3.6e-02 +4.8e-02 -2.2e-02
# Log Per bins:  -0.2091950052836405 1.2013475449906188
# Log amp bins:  -2.091253337507326 -0.9407821623586071
# 0 3
# 0 3
# 3 6
# 3 6
# 6 9.05
# 6 9.05
# 0 3
# 0 3
# 3 6
# 3 6
# 6 9.05
# 6 9.05

# %%
ax_pers_binned.get_xticks()
# Out:
# array([-2.,  0.,  2.,  4.,  6.,  8., 10.])

# %%
friend = ax_pers_binned.get_xticklabels()[0]

# %%
friend.get_text()
# Out:
# '−2'

# %%
[f'M{int(x)}' for x in ax_pers_binned.get_xticks()]
# Out:
# ['M-2', 'M0', 'M2', 'M4', 'M6', 'M8', 'M10']

# %%
(match.approved['SOURCEID'] == periods['SOURCEID']).all()
# Out:
# True

# %%
periods
# Out:
#      index        SOURCEID           shortname A/S/C     RA_deg     DE_deg  \
# 0        0  44989782447631     ic_000C_M2.5_Q2     C  55.704998  31.836398
# 1        1  44989782490916     ic_001C_M5.2_Q2     C  55.756031  32.037304
# 2        2  44989782447074     ic_002A_M3.0_Q0     A  55.778295  31.805697
# 3        3  44989782490480     ic_003C_M1.0_Q2     C  55.807149  32.012534
# 4        4  44989782490350     ic_004C_M4.0_Q2     C  55.815885  32.179310
# ..     ...             ...                 ...   ...        ...        ...
# 382    382  44989782496783     ic_382C_M4.0_Q2     C  56.397747  32.057172
# 383    383  44989782497379     ic_383C_M4.2_Q2     C  56.398515  31.998451
# 384    384  44989782459277  ic_384S_M4.5_Q1JHK     S  56.399668  32.244880
# 385    385  44989782474172     ic_385A_M6.5_Q0     A  56.431685  32.208823
# 386    386  44989782480555     ic_386C_M3.5_Q2     C  56.492729  32.446532
#
#          J_mag      H_mag      K_mag   SpT  ...  poly4_per_amp_H  \
# ...

# %%
np.nanpercentile(periods['Period'][~ir_exc], 16)
# Out:
# 1.1407509527693505

# %%
per_nir_84
# Out:
# nan

# %%
plt.hist?

# %%
ax_amp_hist.axvline?

# %%
np.isfinite?

# %%
ax_amp_hist.errorbar?

# %%
plt.errorbar([1,1][0], [2,2][0], yerr=[[0.5,1], [0.5,1]][0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/_v/s9cr1q_d6kj1m6f7d08s0_cr0000gn/T/ipykernel_49869/640577114.py in <module>
# ----> 1 plt.errorbar([1,1][0], [2,2][0], yerr=[[0.5,1], [0.5,1]][0])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2775         lolims=lolims, uplims=uplims, xlolims=xlolims,
#    2776         xuplims=xuplims, errorevery=errorevery, capthick=capthick,
# -> 2777         **({"data": data} if data is not None else {}), **kwargs)
#    2778
#    2779
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# ...

# %%
10**min_per_bin
# Out:
# 0.6207217235608752

# %%
10**max_per_bin
# Out:
# 57.83262992442209
