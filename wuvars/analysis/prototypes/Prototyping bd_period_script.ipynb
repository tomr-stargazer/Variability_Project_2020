# %%
# %run ../bd_period_script.py
# Out:
# Loading WSERV5 photometry data... DONE (elapsed time: 0.21s)
# Loading WSERV7 photometry data... DONE (elapsed time: 0.22s)
# Loading WSERV8 photometry data... DONE (elapsed time: 0.14s)
# ONC 000 is a periodic candidate (FAP: 1.32e-08)
# ONC 001 is not a periodic candidate (FAP=3.52e-03)
# ONC 002 is not a periodic candidate (FAP=6.95e-03)
# ONC 003 is a periodic candidate (FAP: 2.30e-08)
# ONC 004 is a periodic candidate (FAP: 6.84e-17)
# ONC 005 is not a periodic candidate (FAP=4.60e-03)
# ONC 006 is not a periodic candidate (FAP=4.60e-03)
# ONC 007 is not a periodic candidate (FAP=1.06e-03)
# ONC 008 is a periodic candidate (FAP: 1.07e-06)
# ONC 009 is not a periodic candidate (FAP=8.73e-04)
# ONC 010 is a periodic candidate (FAP: 6.12e-07)
# ONC 011 is a periodic candidate (FAP: 2.30e-08)
# ONC 012 is not a periodic candidate (FAP=4.35e-05)
# ONC 013 is not a periodic candidate (FAP=1.40e-03)
# ONC 014 is not a periodic candidate (FAP=1.66e-05)
# ...

# %%
# %run ../bd_period_script.py
# Out:
# Loading WSERV5 photometry data... DONE (elapsed time: 0.17s)
# Loading WSERV7 photometry data... DONE (elapsed time: 0.18s)
# Loading WSERV8 photometry data... DONE (elapsed time: 0.14s)
# ONC 000 is a periodic candidate (FAP=1.32e-08)
# ONC 001 is not a periodic candidate (FAP=3.52e-03)
# ONC 002 is not a periodic candidate (FAP=6.95e-03)
# ONC 003 is a periodic candidate (FAP=9.67e-14)
# ONC 004 is a periodic candidate (FAP=6.84e-17)
# ONC 005 is not a periodic candidate (FAP=4.60e-03)
# ONC 006 is not a periodic candidate (FAP=4.60e-03)
# ONC 007 is not a periodic candidate (FAP=1.06e-03)
# ONC 008 is a periodic candidate (FAP=1.07e-06)
# ONC 009 is not a periodic candidate (FAP=8.73e-04)
# ONC 010 is a periodic candidate (FAP=6.12e-07)
# ONC 011 is a periodic candidate (FAP=2.30e-08)
# ONC 012 is a periodic candidate (FAP=6.75e-06)
# ONC 013 is not a periodic candidate (FAP=1.40e-03)
# ONC 014 is not a periodic candidate (FAP=1.66e-05)
# ...

# %%
# %run ../bd_period_script.py
# Out:
# Loading WSERV5 photometry data... DONE (elapsed time: 0.23s)
# Loading WSERV7 photometry data... DONE (elapsed time: 0.30s)
# Loading WSERV8 photometry data... DONE (elapsed time: 0.17s)

# %%
mkdir /Users/tsrice/Documents/Variability_Project_2020/Results/folded_lightcurves/IC348/

# %%
ax.vlines?

# %%
plt.suptitle?

# %%
source_properties
# Out:
# <Table length=336>
# index    SOURCEID    ...       per_amp_K             per_fap_K
# int64     int64      ...        float64               float64
# ----- -------------- ... --------------------- ----------------------
#     0 44199508515375 ... -0.006239656862196607 1.3192904969644934e-08
#     1 44199508515199 ...  0.007961430543962068   0.003519722671196624
#     2 44199508515224 ... 0.0068613285923961615    0.02302551215905977
#     3 44199508475055 ... -0.010542102597407389  9.674221051005221e-14
#     4 44199508514291 ...  0.004862143062366124  4.766354441900742e-08
#     5 44199508514565 ...                   0.0                    0.0
#     6 44199508514565 ...                   0.0                    0.0
#     7 44199508514290 ...                   0.0                    0.0
#     8 44199508515004 ...                   0.0                    0.0
#     9 44199508514784 ...                   0.0                    0.0
# ...

# %%
plt.close?

# %%
fap
# Out:
# 0.04280356177148347

# %%
min(fap, min_fap)
# Out:
# 0.04280356177148347
