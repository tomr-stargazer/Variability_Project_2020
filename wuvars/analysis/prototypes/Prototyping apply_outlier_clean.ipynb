# %%
# %run ../../reduction/apply_outlier_clean.py
# Out:
# Starting at: 2024-09-03 20:27:49.655419
# Loading WSERV7 photometry data... DONE (elapsed time: 0.21s)
# Loading WSERV7 photometry data... DONE (elapsed time: 0.21s)
# /Users/tsrice/Documents/Variability_Project_2020/wuvars/reduction/final_outlier_clean.py:409: UserWarning: Warning: converting a masked element to nan.
#   diffs = np.array([left_diff, right_diff])
# /Users/tsrice/Documents/Variability_Project_2020/wuvars/reduction/final_outlier_clean.py:410: UserWarning: Warning: converting a masked element to nan.
#   abs_diffs = np.array([np.abs(left_diff), np.abs(right_diff)])
# Writing to /Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/reduction_artifacts/wserv7/WSERV7_graded_clipped0.95_scrubbed0.1_dusted0.5_new_error_corrected_outlier_cleaned_152.fits
# WSERV7 elapsed time:  0:00:27.977496

# %%
# %debug
# Out:
# > /Users/tsrice/Documents/Variability_Project_2020/wuvars/reduction/apply_outlier_clean.py(53)nullify_outliers()
#      51
#      52                 outlier_selection = cleaned_dataset["MEANMJDOBS"] == b_date
# ---> 53                 assert len(outlier_selection) == 1
#      54                 cleaned_dataset[f"{band}APERMAG3"][outlier_selection] = null
#      55
#
# ipdb> outlier_selection
# array([False, False, False, ..., False, False, False])
# ipdb> np.sum(outlier_selection)
# 18
# ipdb> exit

# %%
from wuvars.reduction.final_outlier_cleaning_script import mark_one_lightcurve
grouped_cleaned_dataset = cleaned_dataset.group_by("SOURCEID")
mark_one_lightcurve(grouped_cleaned_dataset, 44508746107200)
# Out:
# /Users/tsrice/opt/anaconda3/lib/python3.7/site-packages/brokenaxes.py:122: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   if ax.is_last_row():
# /Users/tsrice/opt/anaconda3/lib/python3.7/site-packages/brokenaxes.py:124: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# /Users/tsrice/opt/anaconda3/lib/python3.7/site-packages/brokenaxes.py:252: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   for ax in self.axs if ax.is_last_row())
# /Users/tsrice/opt/anaconda3/lib/python3.7/site-packages/brokenaxes.py:261: MatplotlibDeprecationWarning:
# ...

# %%
from wuvars.data import photometry

new_data = photometry.load_wserv_v2(7, suffix="_outlier_cleaned_152")
# Out:
# Loading WSERV7 photometry data... DONE (elapsed time: 0.05s)

# %%
new_data[new_data['SOURCEID'] == 44508746107200]
# Out:
# <Table length=332>
#    SOURCEID      MEANMJDOBS          RA         ...   HGRADE     KGRADE
#     int64         float64         float64       ...  float32    float32
# -------------- ------------- ------------------ ... ---------- ----------
# 44508746107200   56141.57084 0.9122300781913586 ... 0.99264705 0.99029124
# 44508746107200 56141.5723533 0.9122302079818418 ...  0.9893617 0.98832685
# 44508746107200 56142.6282533 0.9122300498637584 ... 0.99014777  0.9935065
# 44508746107200 56142.6294733 0.9122302408534507 ...        1.0  0.9533074
# 44508746107200 56143.6322367 0.9122300964946632 ...        1.0   0.990228
# 44508746107200 56143.6336767 0.9122302068045643 ...  0.9964539 0.99224806
# 44508746107200 56144.6353733 0.9122300367454791 ...  0.9781553  0.9807074
# 44508746107200 56144.6367667 0.9122301678919496 ...  0.9929078 0.75665396
# 44508746107200 56145.6300833  0.912230055383062 ... 0.99268293 0.99025977
# ...

# %%
data = photometry.load_wserv_v2(7)
ngc_match = match_ngc()
# Out:
# Loading WSERV7 photometry data... DONE (elapsed time: 0.29s)

# %%
data[np.in1d(data["SOURCEID"], ngc_match.approved['SOURCEID'])]
# Out:
# <Table length=27298>
#    SOURCEID      MEANMJDOBS          RA         ...   HGRADE     KGRADE
#     int64         float64         float64       ...  float32    float32
# -------------- ------------- ------------------ ... ---------- ----------
# 44508746095665   56141.56834 0.9180508693848388 ... 0.99568963  0.9774648
# 44508746095665 56142.6255667 0.9180509188358633 ... 0.97849464  0.9886364
# 44508746095665 56143.6297867 0.9180508679488671 ... 0.99568033   0.997151
# 44508746095665   56144.63299 0.9180508729547215 ... 0.98491377  0.9942693
# 44508746095665 56145.6278067 0.9180508516819637 ...   0.995671  0.9830508
# 44508746095665 56146.6273033 0.9180508520636623 ... 0.98275864   0.982906
# 44508746095665   56147.62863 0.9180509059732119 ...  0.9935065  0.9943343
# 44508746095665   56148.58222 0.9180508947439333 ...  0.9934924       0.98
# 44508746095665   56148.58898 0.9180508031138336 ...        0.0  0.9942857
# ...

# %%
    raw_ngc_dat = photometry.load_wserv_v2(7)
# Out:
# Loading WSERV7 photometry data... DONE (elapsed time: 0.28s)

# %%
raw_ngc_dat
# Out:
# <Table length=2319765>
#    SOURCEID      MEANMJDOBS          RA                DEC            JMHPNT     JMHPNTERR      HMKPNT    ... KPPERRBITS MERGEDCLASS    PSTAR      JGRADE     HGRADE     KGRADE
#     int64         float64         float64            float64         float32      float32      float32    ...   int32       int16      float32    float32    float32    float32
# -------------- ------------- ------------------ ------------------ ------------ ------------ ------------ ... ---------- ----------- ----------- ---------- ---------- ----------
# 44508746088477 56262.4593667 0.9106514928459505   0.54980983780995 -999999500.0 1040191740.0 -999999500.0 ...          0           0        0.05        1.0 0.99568963 0.98870057
# 44508746088477   56380.22276 0.9106519229268102 0.5498097526922482 -999999500.0 1040191740.0 -999999500.0 ...    4194368           1        0.05        0.0 0.42857143  0.6472222
# ...
