# %% [markdown]
# # Intention (25 Nov 2023)
# This notebook simply "catalogs" the output of wuvars.analysis.run_results_summary.

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

# %run ../run_results_summary.py
# Out:
# The input catalogs (total):
#
# ***
# NGC 1333
#
# 203 objects in the input catalog
# 155 with an assigned spectral type of M0 or later
#    and are therefore considered for this study.
# (38 have no assigned spectral type)
# (10 have an assigned spectral type earlier than M0)
#
# 155 objects (100.0%) had a positional match within 0.5''
# (0 objects failed to positionally match)
#
# 152 objects' light curves (98.1%) were approved by manual inspection
# (3 light curves were rejected by manual inspection)
# 86 of the 152 approved objects have an IR excess (56.6%)
# Variability analysis
# 152 approved
# 94 statistical
# 90 color
# Number of approved sources that are v1 variables: 51/152
# Number of statistical sources that are v1 variables: 47/94 (50.00%)
# Number of periodic variables found: 54 / 152 (35.53%)
# ***
# IC 348
#
# 478 objects in the input catalog
# 411 with an assigned spectral type of M0 or later
#    and are therefore considered for this study.
# (16 have no assigned spectral type)
# (51 have an assigned spectral type earlier than M0)
#
# 408 objects (99.3%) had a positional match within 0.5''
# (3 objects failed to positionally match)
#
# 387 objects' light curves (94.9%) were approved by manual inspection
# (21 light curves were rejected by manual inspection)
# 158 of the 387 approved objects have an IR excess (40.8%)
# Variability analysis
# 387 approved
# 282 statistical
# 264 color
# Number of approved sources that are v1 variables: 109/387
# Number of statistical sources that are v1 variables: 101/282 (35.82%)
# Number of periodic variables found: 89 / 387 (23.00%)

# %%
np.sum(np.isnan(ngc_match.input_catalog['SpT']))
# Out:
# 38

# %% [markdown]
# # To Coauthors: You can stop reading here.

# %% [markdown]
# # Everything below is from March 2024.

# %%
from wuvars.analysis.prototype2_of_variability_full_criteria import select_stetson_variables

# %%
v2, v1 = select_stetson_variables(7)

# %%
np.sum(v2), np.sum(v1), np.sum(v2 & v1)
# Out:
# (87, 118, 87)

# %%
len(v2)
# Out:
# 21885

# %%
v2_8, v1_8 = select_stetson_variables(8)

# %%
(np.sum(v2_8), np.sum(v1_8), np.sum(v2_8 & v1_8))
# Out:
# (172, 203, 172)

# %%
match.approved
# Out:
# <Table length=387>
#    SOURCEID    median_MEANMJDOBS  ...        DEC              d2d_arcsec
#                                   ...        rad                arcsec
#     int64           float64       ...      float64             float64
# -------------- ------------------ ... ------------------ --------------------
# 44989782447631 56998.803413350004 ... 0.5556502928701313  0.06888532258871657
# 44989782490916      56999.8260475 ... 0.5591574350392777  0.20629453883686533
# 44989782447074 56998.803413350004 ... 0.5551140889388243 0.013112118223946104
# 44989782490480      56999.8260475 ...  0.558724981235728  0.18507615260563737
# 44989782490350      56999.8260475 ... 0.5616353177634286  0.12716493998753753
#            ...                ... ...                ...                  ...
# 44989782496821        56999.32819 ... 0.5594502625026679  0.05447841045068345
# 44989782496783        56999.32819 ... 0.5595031071939089  0.11989935139437155
# 44989782497379       56999.827735 ... 0.5584782110720433  0.17593731926299178
# 44989782459277      56999.3266467 ... 0.5627789932371661  0.06842765856259798
# 44989782474172      56998.2787033 ... 0.5621497050790859  0.09492414957949538
# 44989782480555      56999.3237133 ... 0.5662987405620212  0.06628116622982268

# %%
np.sum(v1[match.approved['SOURCEID']])
# Out:
# 109

# %%
match.approved['SOURCEID'][v1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/_v/s9cr1q_d6kj1m6f7d08s0_cr0000gn/T/ipykernel_36228/1392841811.py in <module>
# ----> 1 match.approved['SOURCEID'][v1]
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins._ColumnGetitemShim.__getitem__()
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins.base_getitem()
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins.column_getitem()
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 387 but corresponding boolean dimension is 27769

# %%
fig2, ax2 = plt.subplots(figsize=(6, 4))

# %%
ax2
# Out:
# <AxesSubplot:>

# %%
# match.approved[approved_v1.values]['SpT']
match.approved['SpT'][approved_v1]
# Out:
# <Column name='SpT' dtype='float64' length=51>
#  4.0
#  9.0
#  4.0
# 8.25
#  3.0
#  6.5
#  5.0
#  7.5
#  ...
#  4.5
#  5.5
#  4.5
#  4.0
# 6.75
# 7.25
#  4.0
#  5.0

# %%
match.approved
# Out:
# <Table length=152>
#    SOURCEID    median_MEANMJDOBS ...        DEC              d2d_arcsec
#                                  ...        rad                arcsec
#     int64           float64      ...      float64             float64
# -------------- ----------------- ... ------------------ --------------------
# 44508746127015       56243.57007 ... 0.5461392180741246  0.09644934285439379
# 44508746126979       56241.52595 ... 0.5461130381353446  0.09674995205188383
# 44508746098759     56241.5245967 ... 0.5458386335918366  0.07541240879617454
# 44508746098738      56239.037275 ... 0.5455152628665365   0.1470840811263741
# 44508746098719     56242.4354033 ...  0.546017045026485  0.09262083102220983
#            ...               ... ...                ...                  ...
# 44508746108258    56243.98506335 ... 0.5424153641895222  0.06791191886080727
# 44508746108270    56243.98506335 ... 0.5424046982885378   0.0666131729180516
# 44508746117885     56243.0047167 ... 0.5470608488819138 0.029191595887158323
# 44508746129880     56242.4367867 ... 0.5471267835425446  0.01521433160455302
# 44508746130001     56242.4367867 ... 0.5487189116713084 0.020269622978450114
# 44508746095665     56241.5245967 ... 0.5451458348415311  0.24859862991297635

# %%
match.approved['var_Stetson_JHK']
# Out:
# <MaskedColumn name='var_Stetson_JHK' dtype='float64' length=387>
#   2.2353222779553343
#   0.9073756426230244
#       0.941162109375
#   23.204067887931036
#     4.74023577810704
#  0.36202386878002646
# -0.10960409376356336
#    8.795645480685764
#   0.9124534924825032
#   0.8101268181434045
#   0.4822243876840876
#   14.745494106359647
#   13.911473767510774
#    0.753202342023753
#  0.33047020572355423
#   0.6529056279346196
#   0.9109682569316788
#    0.675539353314568
#                  ...
#   1.3629024212176983
#    1.931639546095723
#  0.07295299298835523
#   0.9197611490885416
#  0.34669210260564626
#   0.5737444174410117
#    6.019870087594697
#   3.5553267045454544
#    2.573904018209438
#   2.4921545163549554
#  0.31053353398224043
#    4.307031702112268
#   1.1983503861860796
#    2.404534172289299
#    2.195543693773674
#   0.8983116869656544
#   24.193284377553102

# %%
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_v/s9cr1q_d6kj1m6f7d08s0_cr0000gn/T/ipykernel_36228/2369097233.py in <module>
# ----> 1 ds
#
# NameError: name 'ds' is not defined

# %%
np.in1d(match.approved['SOURCEID'], v_per.index)
# Out:
# array([False, False, False, False,  True, False, False, False, False,
#        False, False, False,  True, False, False, False, False,  True,
#        False, False,  True, False, False, False, False, False,  True,
#        False, False, False, False,  True,  True, False, False,  True,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False,  True,  True,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False,  True, False, False,  True, False,
#        False,  True, False, False, False, False,  True,  True, False,
#         True,  True,  True,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False,  True,
#        False, False, False,  True, False, False,  True, False, False,
#         True,  True, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False])

# %%
v_per.index
# Out:
# Int64Index([44508746098719, 44508746128322, 44508746098403, 44508746098400,
#             44508746107325, 44508746107378, 44508746116168, 44508746116177,
#             44508746116243, 44508746116314, 44508746116316, 44508746116558,
#             44508746116731, 44508746117253, 44508746116800, 44508746116840,
#             44508746117257, 44508746116914, 44508746116949, 44508746116989,
#             44508746116994, 44508746116999, 44508746117406, 44508746117427,
#             44508746107212, 44508746117537, 44508746117569, 44508746117584,
#             44508746117684],
#            dtype='int64', name='SOURCEID')

# %%
periodics = np.in1d(match.approved['SOURCEID'], v_per.index)

# %%
match.approved['SOURCEID'][periodics]
# Out:
# <Column name='SOURCEID' dtype='int64' length=29>
# 44508746098719
# 44508746128322
# 44508746098403
# 44508746098400
# 44508746107325
# 44508746107378
# 44508746116168
# 44508746116177
# 44508746116243
# 44508746116314
# 44508746116316
# 44508746116558
# 44508746116731
# 44508746117253
# 44508746116800
# 44508746116840
# 44508746117257
# 44508746116914
# 44508746116949
# 44508746116989
# 44508746116994
# 44508746116999
# 44508746117406
# 44508746117427
# 44508746107212
# 44508746117537
# 44508746117569
# 44508746117584
# 44508746117684

# %%
v_per
# Out:
#                 index           shortname  ...       Amp  Color? (dK/dJ)
# SOURCEID                                   ...
# 44508746098719      3    ngc_003A_M8.0_Q0  ...  0.014748        0.703554
# 44508746128322      8  ngc_008S_M9.0_Q1HK  ...  0.059975             NaN
# 44508746098403     12    ngc_012C_M8.2_Q2  ...  0.021838        1.060816
# 44508746098400     14  ngc_014A_M6.5_Q1JH  ...  0.049800        0.531890
# 44508746107325     19    ngc_019C_M7.5_Q2  ...  0.025821             NaN
# 44508746107378     22    ngc_022C_M8.2_Q2  ...  0.013737        0.791245
# 44508746116168     23   ngc_023A_M6.0_Q1J  ...  0.012353             NaN
# 44508746116177     24    ngc_024C_M6.5_Q2  ...  0.011626        0.813566
# 44508746116243     28    ngc_028C_M6.5_Q2  ...  0.007455             NaN
# 44508746116314     34    ngc_034A_M8.0_Q0  ...  0.064903             NaN
# 44508746116316     35    ngc_035C_M5.5_Q2  ...  0.008009        0.783300
# 44508746116558     41    ngc_041C_M8.2_Q2  ...  0.025146             NaN
# 44508746116731     55    ngc_055C_M7.8_Q2  ...  0.036622             NaN
# 44508746117253     57    ngc_057A_M6.0_Q0  ...  0.035795        0.777828
# 44508746116800     60    ngc_060C_M5.5_Q2  ...  0.095736             NaN
# 44508746116840     63    ngc_063C_M5.0_Q2  ...  0.028422        0.821787
# 44508746117257     67    ngc_067C_M8.0_Q2  ...  0.020041        0.761643
# 44508746116914     68    ngc_068C_M4.5_Q2  ...  0.012000        1.200000
# 44508746116949     70    ngc_070C_M9.0_Q2  ...  0.022168             NaN
# 44508746116989     71    ngc_071C_M6.2_Q2  ...  0.018701        0.958169
# 44508746116994     72    ngc_072C_M5.2_Q2  ...  0.012000             NaN
# 44508746116999     73    ngc_073C_M7.5_Q2  ...  0.008821             NaN
# 44508746117406     82    ngc_082C_M4.8_Q2  ...  0.045303        0.650461
# 44508746117427     85    ngc_085C_M5.5_Q2  ...  0.007435             NaN
# 44508746107212     88    ngc_088C_M7.5_Q2  ...  0.041032        0.917502
# 44508746117537     90    ngc_090C_M4.5_Q2  ...  0.016425             NaN
# 44508746117569     92    ngc_092C_M5.5_Q2  ...  0.086886        0.741920
# 44508746117584     93    ngc_093C_M4.5_Q2  ...  0.167475        0.465149
# 44508746117684     99    ngc_099C_M6.8_Q2  ...  0.012147        0.712046
#
# [29 rows x 27 columns]

# %%
match.approved.columns
# Out:
# <TableColumns names=('SOURCEID','median_MEANMJDOBS','median_RA','median_DEC','median_JMHPNT','median_JMHPNTERR','median_HMKPNT','median_HMKPNTERR','median_JAPERMAG3','median_JAPERMAG3ERR','median_HAPERMAG3','median_HAPERMAG3ERR','median_KAPERMAG3','median_KAPERMAG3ERR','median_JPPERRBITS','median_HPPERRBITS','median_KPPERRBITS','median_MERGEDCLASS','median_PSTAR','median_JGRADE','median_HGRADE','median_KGRADE','var_J_red_chisq','var_H_red_chisq','var_K_red_chisq','var_Stetson_HK','var_Stetson_JK','var_Stetson_JH','var_Stetson_JHK','std_MEANMJDOBS','std_RA','std_DEC','std_JMHPNT','std_JMHPNTERR','std_HMKPNT','std_HMKPNTERR','std_JAPERMAG3','std_JAPERMAG3ERR','std_HAPERMAG3','std_HAPERMAG3ERR','std_KAPERMAG3','std_KAPERMAG3ERR','std_JPPERRBITS','std_HPPERRBITS','std_KPPERRBITS','std_MERGEDCLASS','std_PSTAR','std_JGRADE','std_HGRADE','std_KGRADE','range_MEANMJDOBS','range_RA','range_DEC','range_JMHPNT','range_JMHPNTERR','range_HMKPNT','range_HMKPNTERR','range_JAPERMAG3','range_JAPERMAG3ERR','range_HAPERMAG3','range_HAPERMAG3ERR','range_KAPERMAG3','range_KAPERMAG3ERR','range_JPPERRBITS','range_HPPERRBITS','range_KPPERRBITS','range_MERGEDCLASS','range_PSTAR','range_JGRADE','range_HGRADE','range_KGRADE','Name','RAh','RAm','RAs','DE-','DEd','DEm','DEs','Luhman','Evans','Stelzer','AlvesdeOliveira','OtherNames','SpType','r_SpType','Spectrograph','Date','Adopt','Aj','IRexc','pmRA','e_pmRA','pmDE','e_pmDE','Jmag','e_Jmag','Hmag','e_Hmag','Ksmag','e_Ksmag','JHKref','SpT','Teff','RA','DEC','d2d_arcsec')>

# %% [markdown]
# # 15 Sep 2024

# %%
v_per
# Out:
#                 index         shortname A/S/C     RA_deg     DE_deg  \
# SOURCEID
# 44989782441467     13   ic_013C_M4.5_Q2     C  55.953389  32.264297
# 44989782469408     16   ic_016C_M5.8_Q2     C  55.980288  32.131460
# 44989782469336     18   ic_018C_M7.2_Q2     C  55.984944  32.166440
# 44989782441140     20   ic_020C_M6.0_Q2     C  55.989763  32.246907
# 44989782468907     41   ic_041C_M4.8_Q2     C  56.031285  32.069112
# 44989782468661     46   ic_046C_M5.2_Q2     C  56.046752  32.137827
# 44989782468550     49   ic_049C_M5.5_Q2     C  56.053174  32.182015
# 44989782426518     52   ic_052C_M5.5_Q2     C  56.057748  31.948294
# 44989782468260     61   ic_061C_M5.2_Q2     C  56.074040  32.079902
# 44989782426377     62   ic_062C_M6.0_Q2     C  56.075351  31.949990
# 44989782443309     67   ic_067C_M6.8_Q2     C  56.079249  32.368250
# 44989782467954     71   ic_071C_M4.8_Q2     C  56.084480  32.095483
# 44989782441281     73   ic_073C_M4.8_Q2     C  56.089829  32.252719
# 44989782467561     83   ic_083C_M5.5_Q2     C  56.107325  32.151650
# 44989782467541     86  ic_086A_M4.8_Q1J     A  56.110987  32.066206
# 44989782442939     91   ic_091C_M5.0_Q2     C  56.113406  32.341336
# 44989782467400     95   ic_095C_M5.5_Q2     C  56.116575  32.088795
# 44989782467337     96   ic_096C_M5.8_Q2     C  56.120325  32.073027
# 44989782440424    111   ic_111C_M4.5_Q2     C  56.132706  32.212260
# 44989782466801    130   ic_130C_M8.8_Q2     C  56.151573  32.051520
# 44989782466756    133   ic_133C_M4.8_Q2     C  56.154107  32.142840
# 44989782494471    136   ic_136A_M4.5_Q0     A  56.157406  32.205048
# 44989782455528    154   ic_154A_M4.8_Q0     A  56.174456  32.299075
# 44989782496654    186   ic_186C_M5.2_Q2     C  56.241056  32.067096
# 44989782458010    211   ic_211C_M5.0_Q2     C  56.309778  32.264679
#
#                     J_mag      H_mag      K_mag     Teff   SpT  ...  \
# SOURCEID                                                        ...
# 44989782441467  12.962186  12.183146  11.761762  3197.50  4.50  ...
# 44989782469408  13.618105  13.064168  12.544687  3023.75  5.75  ...
# 44989782469336  15.415442  14.685241  14.074310  2837.50  7.25  ...
# 44989782441140  14.935631  14.304154  13.781755  2990.00  6.00  ...
# 44989782468907  13.323595  12.644284  12.207322  3161.25  4.75  ...
# 44989782468661  12.762792  12.137851  11.710960  3091.25  5.25  ...
# 44989782468550  14.583703  13.973659  13.528593  3057.50  5.50  ...
# 44989782426518  15.539492  14.034251  13.016246  3057.50  5.50  ...
# 44989782468260  13.139214  12.357058  11.861967  3091.25  5.25  ...
# 44989782426377  15.379261  14.639040  14.080578  2990.00  6.00  ...
# 44989782443309  14.493757  13.810040  13.252711  2907.50  6.75  ...
# 44989782467954  14.230672  13.386982  12.850569  3161.25  4.75  ...
# 44989782441281  12.973669  12.280738  11.923682  3161.25  4.75  ...
# 44989782467561  14.654086  13.803722  13.226917  3057.50  5.50  ...
# 44989782467541  11.767659  10.987535  10.603686  3161.25  4.75  ...
# 44989782442939  13.685469  12.991987  12.496510  3125.00  5.00  ...
# 44989782467400  14.837549  14.240742  13.789338  3057.50  5.50  ...
# 44989782467337  15.051009  14.355800  13.791449  3023.75  5.75  ...
# 44989782440424  14.672596  13.406157  12.702225  3197.50  4.50  ...
# 44989782466801  16.611345  15.900920  15.214778  2477.50  8.75  ...
# 44989782466756  12.973644  12.112554  11.614726  3161.25  4.75  ...
# 44989782494471  12.838722  12.030956  11.618690  3197.50  4.50  ...
# 44989782455528  13.596179  12.820187  12.374246  3161.25  4.75  ...
# 44989782496654  13.469654  12.818561  12.425721  3091.25  5.25  ...
# 44989782458010  14.615941  13.751711  13.221157  3125.00  5.00  ...
#
#                 per_amp_H     per_fap_H  period_K  per_amp_K     per_fap_K  \
# SOURCEID
# 44989782441467   0.022939  1.238214e-18  2.876031   0.019570  3.780278e-14
# 44989782469408   0.017775  1.471650e-05  2.240636   0.018094  2.921694e-05
# 44989782469336   0.010093  5.207693e-06  0.618465   0.008179  1.955901e-03
# 44989782441140   0.022035  2.943074e-13  0.681707   0.015091  2.238051e-11
# 44989782468907   0.016992  3.325386e-06  0.698858   0.013126  1.753859e-07
# 44989782468661   0.011929  1.796712e-06  0.706262   0.010677  2.708087e-03
# 44989782468550   0.020756  8.956818e-15  1.326079   0.015615  2.367346e-11
# 44989782426518   0.016908  5.334759e-14  0.636130   0.014913  4.805153e-12
# 44989782468260   0.015359  5.881504e-07  0.866097   0.015217  2.256631e-08
# 44989782426377   0.011483  2.732254e-07  1.546067   0.010296  8.567944e-02
# 44989782443309   0.008105  1.733967e-11  1.790503   0.006969  1.030947e-03
# 44989782467954   0.012125  6.622465e-08  1.773357   0.008132  1.145457e-03
# 44989782441281   0.036029  4.503232e-20  8.130047   0.028981  3.310294e-16
# 44989782467561   0.011622  1.445978e-08  2.700502   0.009239  1.253306e-05
# 44989782467541   0.016697  1.495041e-06  1.473833   0.018200  7.221570e-07
# 44989782442939   0.012451  5.369668e-08  1.688612   0.010441  1.448172e-04
# 44989782467400   0.008890  1.029231e-10  1.698362   0.007558  8.896677e-05
# 44989782467337   0.008577  2.833356e-05  0.056478   0.007281  1.747996e-02
# 44989782440424   0.022326  9.795821e-08  3.100762   0.016774  1.113285e-02
# 44989782466801   0.042158  2.900904e-17  1.450110   0.028454  4.909494e-10
# 44989782466756   0.016383  8.235119e-10  2.457596   0.015263  1.276967e-04
# 44989782494471   0.017877  6.277957e-06  3.249905   0.015783  3.369961e-07
# 44989782455528   0.017136  1.796736e-12  1.792428   0.014609  8.015441e-14
# 44989782496654   0.013031  1.007696e-07  2.302546   0.010188  6.430202e-07
# 44989782458010   0.012948  2.346657e-17  0.823516   0.011753  4.069379e-13
#
#                 Periodic?    Period       Amp  Color? (dK/dJ)  \
# SOURCEID
# 44989782441467          Y  2.876031  0.020699        0.999127
# 44989782469408        YfY  2.240636  0.019327        0.818257
# 44989782469336         Yw  0.617968  0.009687        0.758059
# 44989782441140          Y  0.681815  0.020997        0.583430
# 44989782468907        YfY  2.337500     0.015             NaN
# 44989782468661         Yw  0.706062  0.011929        1.489507
# 44989782468550          Y  1.326020  0.016736        1.128500
# 44989782426518          Y  0.636197   0.01569        0.977846
# 44989782468260          Y  0.865797  0.015489        0.957695
# 44989782426377          Y  1.547103  0.011409        0.827099
# 44989782443309         Yw  1.789862  0.007897        0.808699
# 44989782467954        YfY  2.277895  0.012125             NaN
# 44989782441281          Y  8.121252  0.031264        1.006889
# 44989782467561        YfY  2.700502  0.009239             NaN
# 44989782467541          Y  1.473037  0.018215        0.921587
# 44989782442939        YfY  2.440000  0.012451             NaN
# 44989782467400          Y  1.698171  0.008249        0.910602
# 44989782467337        YfY  2.780000  0.008577             NaN
# 44989782440424        YfY  3.100762  0.016774             NaN
# 44989782466801          Y  1.449550   0.04189        0.516792
# 44989782466756        YfY  2.457596  0.015263        1.166667
# 44989782494471          Y  3.252373  0.015821        1.143397
# 44989782455528          Y  1.792107  0.015007        0.948352
# 44989782496654          Y  2.300427  0.013031             NaN
# 44989782458010          Y  0.823471  0.012015        1.036108
#
#                                                             Notes
# SOURCEID
# 44989782441467                                                NaN
# 44989782469408  Complex behavior; yes is periodic with 2.24d, ...
# 44989782469336                                                NaN
# 44989782441140                                                NaN
# 44989782468907                                                NaN
# 44989782468661                                                NaN
# 44989782468550                                                NaN
# 44989782426518                                                NaN
# 44989782468260                                                NaN
# 44989782426377                                                NaN
# 44989782443309                                                NaN
# 44989782467954  2.28 seems like the winner (tiebreaking by hig...
# 44989782441281                                                NaN
# 44989782467561                            Detrending suggest 2.7d
# 44989782467541                                                NaN
# 44989782442939                          Detrending suggests 2.44d
# 44989782467400                                                NaN
# 44989782467337  I think 2.78 is the winner but something else ...
# 44989782440424                                                NaN
# 44989782466801                                                NaN
# 44989782466756                                                NaN
# 44989782494471                                                NaN
# 44989782455528                                                NaN
# 44989782496654                                                NaN
# 44989782458010                                                NaN
#
# [25 rows x 28 columns]

# %%
# %run ../load_periodics_v4.py

# %%
select_periodic_variables_v4(8)
# Out:
#                 index        shortname A/S/C     RA_deg     DE_deg      J_mag  \
# SOURCEID
# 44989782470026     16  ic_016C_M3.0_Q2     C  55.901296  32.062076  15.471591
# 44989782441467     27  ic_027C_M4.5_Q2     C  55.953389  32.264297  12.962186
# 44989782469660     28  ic_028C_M3.5_Q2     C  55.955818  32.177737  12.667867
# 44989782469500     31  ic_031A_M4.2_Q0     A  55.974194  32.125060  13.760868
# 44989782469408     34  ic_034C_M5.8_Q2     C  55.980288  32.131460  13.618105
# ...               ...              ...   ...        ...        ...        ...
# 44989782458010    361  ic_361C_M5.0_Q2     C  56.309778  32.264679  14.615941
# 44989782495270    370  ic_370C_M4.0_Q2     C  56.337104  32.154375  13.759777
# 44989782458378    371  ic_371A_M4.5_Q0     A  56.337761  32.304933  12.839343
# 44989782496585    377  ic_377C_M2.0_Q2     C  56.369627  32.071762  13.785323
# 44989782496821    381  ic_381C_M3.0_Q2     C  56.384601  32.054138  12.884482
#
#                     H_mag      K_mag   SpT  Stetson_JHK  ...  poly4_per_amp_H  \
# SOURCEID                                                 ...
# 44989782470026  13.604097  12.479017  3.00     0.910968  ...         0.010189
# 44989782441467  12.183146  11.761762  4.50     3.043724  ...         0.021912
# 44989782469660  11.934713  11.588063  3.50     2.681644  ...         0.018456
# 44989782469500  12.969007  12.537784  4.25     0.946588  ...         0.009307
# 44989782469408  13.064168  12.544687  5.75     3.151438  ...         0.014378
# ...                   ...        ...   ...          ...  ...              ...
# 44989782458010  13.751711  13.221157  5.00     1.405063  ...         0.012931
# 44989782495270  12.954367  12.548572  4.00     1.362902  ...         0.010602
# 44989782458378  11.914791  11.410932  4.50     1.931640  ...         0.013647
# 44989782496585  12.546539  11.966821  2.00     3.555327  ...         0.023171
# 44989782496821  12.182103  11.916998  3.00     4.307032  ...         0.030141
#
#                 poly4_per_fap_H  poly4_period_K  poly4_per_amp_K  \
# SOURCEID
# 44989782470026     1.862771e-05        0.876497         0.008945
# 44989782441467     4.604664e-14        2.880172         0.017819
# 44989782469660     9.143543e-12       12.886544         0.016064
# 44989782469500     6.569235e-07        2.168718         0.009736
# 44989782469408     2.954779e-04        2.241641         0.015199
# ...                         ...             ...              ...
# 44989782458010     9.888937e-16        0.823584         0.011828
# 44989782495270     4.332151e-08        1.653706         0.011147
# 44989782458378     1.136296e-10        4.999979         0.012541
# 44989782496585     5.765136e-18        6.464097         0.022453
# 44989782496821     3.002573e-13        0.413204         0.024901
#
#                 poly4_per_fap_K  Periodic?     Period       Amp   Method  \
# SOURCEID
# 44989782470026     8.907917e-04          Y   7.214977  0.010189    poly4
# 44989782441467     6.143061e-10          Y   2.876858  0.019588  vanilla
# 44989782469660     2.528721e-11          Y  12.903172  0.017170  vanilla
# 44989782469500     3.708671e-08          Y   2.169188  0.009703    poly2
# 44989782469408     6.169672e-04          Y   2.240636  0.022112  vanilla
# ...                         ...        ...        ...       ...      ...
# 44989782458010     6.452521e-13          Y   0.823448  0.012948  vanilla
# 44989782495270     4.196594e-10          Y   1.653706  0.011147    poly4
# 44989782458378     1.808858e-13          Y   5.020059  0.012759  vanilla
# 44989782496585     3.639568e-15          Y   6.485057  0.022386  vanilla
# 44989782496821     7.735963e-10          Y   0.705464  0.028994  vanilla
#
#                 Best Band
# SOURCEID
# 44989782470026          H
# 44989782441467          J
# 44989782469660          J
# 44989782469500          K
# 44989782469408          J
# ...                   ...
# 44989782458010          H
# 44989782495270          K
# 44989782458378          K
# 44989782496585          J
# 44989782496821          H
#
# [89 rows x 45 columns]

# %%
spread['median']['HMKPNT']
# Out:
# SOURCEID
# 44508746088477   NaN
# 44508746088478   NaN
# 44508746088482   NaN
# 44508746088484   NaN
# 44508746088487   NaN
#                   ..
# 44508746139098   NaN
# 44508746139125   NaN
# 44508746139158   NaN
# 44508746139174   NaN
# 44508746139200   NaN
# Name: HMKPNT, Length: 21885, dtype: float64

# %%
ngc_match.statistical
# Out:
# <Table length=94>
#    SOURCEID    median_MEANMJDOBS     median_RA          median_DEC        median_JMHPNT    ...   SpT     Teff          RA                DEC              d2d_arcsec
#                                                                                            ...                        rad                rad                arcsec
#     int64           float64           float64            float64             float64       ... float64 float64      float64            float64             float64
# -------------- ----------------- ------------------ ------------------ ------------------- ... ------- ------- ------------------ ------------------ --------------------
# 44508746126979       56241.52595 0.9086759217997056 0.5461125721574945   0.689478874206543 ...    8.25  2632.5 0.9086758590094592 0.5461130381353446  0.09674995205188383
# 44508746098671     56240.5163467 0.9101066779434371 0.5457280799302613   1.037515640258789 ...     8.0  2710.0 0.9101063017755731 0.5457285808862247  0.12278179366302984
# 44508746126973    56241.52527335 0.9102100822970738 0.5461004869369863  0.7155437469482422 ...     8.5  2555.0 0.9102095670896494 0.5461004329796358  0.09149241849035428
# 44508746127275       56243.57007 0.9102271905189312 0.5467196472541143  0.6108312606811523 ...     4.0  3270.0 0.9102270203821693 0.5467190552367315  0.12573821122534065
# 44508746128322     56242.4367867 0.9103907252963144 0.5463206543671744                  -- ...     9.0  2400.0 0.9103899177790221 0.5463205383908595  0.14431437036056557
# 44508746098496     56241.5245967 0.9107151056549578 0.5441678681271309   2.059793472290039 ...     4.0  3270.0 0.9107149853522061 0.5441679656467332 0.029245876201739945
# 44508746127412       56243.57007 0.9107769362925472 0.5471262837459905  0.8692340850830078 ...     6.0  2990.0 0.9107767990965475 0.5471262987288635 0.024364540507686338
# 44508746098403     56241.5245967 0.9110140618931667 0.5443967315207437  1.5559921264648438 ...    8.25  2632.5 0.9110138729866101  0.544397282517898  0.11843836430820762
# 44508746127678       56243.57007 0.9110361042837648 0.5480632607500145  1.5307331085205078 ...     3.0  3415.0 0.9110349623817383 0.5480634435744483  0.20454297405926364
# 44508746127488    56243.00342835 0.9110373785984369 0.5474255422910967  1.3055191040039062 ...    8.25  2632.5 0.9110371440433034 0.5474254287701081   0.0474851339215675
# 44508746126974     56260.4856033 0.9111216951390133 0.5461065316671737   2.472702980041504 ...     5.0  3125.0 0.9111207744032948 0.5461067355574902  0.16765320849773643
# 44508746116074     56243.0047167 0.9112770730085142 0.5479753959128144   2.120931625366211 ...     2.5  3487.5 0.9112771268154526 0.5479752074844862  0.04000403135013027
# 44508746107194    56243.98506335 0.9112841781851526 0.5458637878207351  0.6971445083618164 ...     5.0  3125.0 0.9112843990206693 0.5458638439032543  0.04061341071580752
# 44508746107325    56243.98506335 0.9113624268857187 0.5456441580484562  0.5460853576660156 ...     7.5  2795.0 0.9113622116164873 0.5456442233057117    0.040271022785113
# 44508746107213    56243.98506335 0.9114185856701484 0.5458348201939816  0.6244821548461914 ...     5.0  3125.0 0.9114182075966554 0.5458352398960689  0.10925562350704171
#            ...               ...                ...                ...                 ... ...     ...     ...                ...                ...                  ...
# 44508746121420     56243.5713867 0.9140364979073222 0.5406730414959219  0.5887036323547363 ...    4.75 3161.25 0.9140354742541252 0.5406729438196145  0.18214430473072127
# 44508746117537     56243.0047167  0.914100856601067 0.5471733787541471  0.9227809906005859 ...     4.5  3197.5 0.9141001968805534 0.5471738104696123  0.14640415713579671
# 44508746117549     56243.0047167 0.9141557722035962 0.5490412237541198  0.6967849731445312 ...     5.5  3057.5 0.9141561928607215 0.5490413127692462  0.07625760403323603
# 44508746117569     56242.4380467 0.9142287024550718 0.5484588767538692  0.8950099945068359 ...     5.5  3057.5 0.9142281876923664 0.5484590515382337  0.09751344606076298
# 44508746117584     56243.0047167 0.9143031308474574 0.5482124127115198  0.9113950729370117 ...     4.5  3197.5 0.9143023641855761   0.54821276618823  0.15339663303025483
# 44508746117586     56243.0047167 0.9143251471840377 0.5489669292213856   0.683558464050293 ...     4.0  3270.0 0.9143249080217477 0.5489676210897175   0.1487834583250323
# 44508746117604     56242.4380467 0.9143985450489887 0.5470450987038901  0.5915937423706055 ...     8.0  2710.0 0.9143983572944357 0.5470453348441182 0.058876162197896695
# 44508746117626     56243.0047167 0.9144289836724938 0.5462072387486836  0.6442117691040039 ...    3.25 3378.75 0.9144296277768673 0.5462070919894799  0.11749219303875302
# 44508746117655     56242.4380467  0.914578841137683 0.5462386446327832  0.7043704986572266 ...     9.0  2400.0 0.9145787079838085 0.5462390896924332   0.0947524718301839
# 44508746120771     56243.5713867 0.9146719697381573 0.5418719342501821 0.46750879287719727 ...     6.5  2935.0 0.9146717922105816 0.5418723728666796  0.09575610398855233
# 44508746117684     56243.0047167 0.9146780494027609 0.5474638933166172  0.4845905303955078 ...    6.75  2907.5 0.9146776099747549 0.5474642138645969  0.10178898743162924
# 44508746117813     56242.4380467 0.9151448091776996 0.5468085845723617  1.1510143280029297 ...    7.25  2837.5  0.915145212770185 0.5468087457677367   0.0784978777035039
# 44508746117885     56243.0047167 0.9153088273898977  0.547060990148952  0.5627069473266602 ...     4.5  3197.5 0.9153088373875594 0.5470608488819138 0.029191595887158323
# 44508746130001     56242.4367867 0.9160957939955764 0.5487188694452019  0.7663693428039551 ...     2.0  3560.0 0.9160956899920003 0.5487189116713084 0.020269622978450114
# 44508746095665     56241.5245967 0.9180508679488671 0.5451451218093873  0.5630359649658203 ...     5.0  3125.0 0.9180497315337122 0.5451458348415311  0.24859862991297635
