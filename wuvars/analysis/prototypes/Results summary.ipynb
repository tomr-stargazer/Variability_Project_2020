# %% [markdown]
# # Intention (25 Nov 2023)
# This notebook simply "catalogs" the output of wuvars.analysis.run_results_summary.

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

# %run ../run_results_summary.py
# Out:
# The input catalogs (total):
#
# ***
# NGC 1333
#
# 203 objects in the input catalog
# 155 with an assigned spectral type of M0 or later
#    and are therefore considered for this study.
# (38 have no assigned spectral type)
# (10 have an assigned spectral type earlier than M0)
#
# 155 objects (100.0%) had a positional match within 0.5''
# (0 objects failed to positionally match)
#
# 152 objects' light curves (98.1%) were approved by manual inspection
# (3 light curves were rejected by manual inspection)
# Variability analysis
# 152 approved
# 94 statistical
# 90 color
# Number of approved sources that are v1 variables: 51/152
# Number of statistical sources that are v1 variables: 47/94 (50.00%)
# Len of v_per: 29
# TBD
#
# ***
# IC 348
#
# 478 objects in the input catalog
# 411 with an assigned spectral type of M0 or later
#    and are therefore considered for this study.
# (16 have no assigned spectral type)
# (51 have an assigned spectral type earlier than M0)
#
# 408 objects (99.3%) had a positional match within 0.5''
# (3 objects failed to positionally match)
#
# 387 objects' light curves (94.9%) were approved by manual inspection
# (21 light curves were rejected by manual inspection)
# Variability analysis
# 387 approved
# 282 statistical
# 264 color
# Number of approved sources that are v1 variables: 109/387
# Number of statistical sources that are v1 variables: 101/282 (35.82%)
# Len of v_per: 25
# TBD

# %%
np.sum(np.isnan(ngc_match.input_catalog['SpT']))
# Out:
# 38

# %% [markdown]
# # Everything above is from 25 Nov 2023
#
# Everything below is from March 2024.

# %%
from wuvars.analysis.prototype2_of_variability_full_criteria import select_stetson_variables

# %%
v2, v1 = select_stetson_variables(7)

# %%
np.sum(v2), np.sum(v1), np.sum(v2 & v1)
# Out:
# (87, 118, 87)

# %%
len(v2)
# Out:
# 21885

# %%
v2_8, v1_8 = select_stetson_variables(8)

# %%
(np.sum(v2_8), np.sum(v1_8), np.sum(v2_8 & v1_8))
# Out:
# (172, 203, 172)

# %%
match.approved
# Out:
# <Table length=387>
#    SOURCEID    median_MEANMJDOBS  ...        DEC              d2d_arcsec
#                                   ...        rad                arcsec
#     int64           float64       ...      float64             float64
# -------------- ------------------ ... ------------------ --------------------
# 44989782447631 56998.803413350004 ... 0.5556502928701313  0.06888532258871657
# 44989782490916      56999.8260475 ... 0.5591574350392777  0.20629453883686533
# 44989782447074 56998.803413350004 ... 0.5551140889388243 0.013112118223946104
# 44989782490480      56999.8260475 ...  0.558724981235728  0.18507615260563737
# 44989782490350      56999.8260475 ... 0.5616353177634286  0.12716493998753753
#            ...                ... ...                ...                  ...
# 44989782496821        56999.32819 ... 0.5594502625026679  0.05447841045068345
# 44989782496783        56999.32819 ... 0.5595031071939089  0.11989935139437155
# 44989782497379       56999.827735 ... 0.5584782110720433  0.17593731926299178
# 44989782459277      56999.3266467 ... 0.5627789932371661  0.06842765856259798
# 44989782474172      56998.2787033 ... 0.5621497050790859  0.09492414957949538
# 44989782480555      56999.3237133 ... 0.5662987405620212  0.06628116622982268

# %%
np.sum(v1[match.approved['SOURCEID']])
# Out:
# 109

# %%
match.approved['SOURCEID'][v1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/_v/s9cr1q_d6kj1m6f7d08s0_cr0000gn/T/ipykernel_36228/1392841811.py in <module>
# ----> 1 match.approved['SOURCEID'][v1]
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins._ColumnGetitemShim.__getitem__()
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins.base_getitem()
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins.column_getitem()
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 387 but corresponding boolean dimension is 27769

# %%
fig2, ax2 = plt.subplots(figsize=(6, 4))

# %%
ax2
# Out:
# <AxesSubplot:>

# %%
# match.approved[approved_v1.values]['SpT']
match.approved['SpT'][approved_v1]
# Out:
# <Column name='SpT' dtype='float64' length=51>
#  4.0
#  9.0
#  4.0
# 8.25
#  3.0
#  6.5
#  5.0
#  7.5
#  ...
#  4.5
#  5.5
#  4.5
#  4.0
# 6.75
# 7.25
#  4.0
#  5.0

# %%
match.approved
# Out:
# <Table length=152>
#    SOURCEID    median_MEANMJDOBS ...        DEC              d2d_arcsec
#                                  ...        rad                arcsec
#     int64           float64      ...      float64             float64
# -------------- ----------------- ... ------------------ --------------------
# 44508746127015       56243.57007 ... 0.5461392180741246  0.09644934285439379
# 44508746126979       56241.52595 ... 0.5461130381353446  0.09674995205188383
# 44508746098759     56241.5245967 ... 0.5458386335918366  0.07541240879617454
# 44508746098738      56239.037275 ... 0.5455152628665365   0.1470840811263741
# 44508746098719     56242.4354033 ...  0.546017045026485  0.09262083102220983
#            ...               ... ...                ...                  ...
# 44508746108258    56243.98506335 ... 0.5424153641895222  0.06791191886080727
# 44508746108270    56243.98506335 ... 0.5424046982885378   0.0666131729180516
# 44508746117885     56243.0047167 ... 0.5470608488819138 0.029191595887158323
# 44508746129880     56242.4367867 ... 0.5471267835425446  0.01521433160455302
# 44508746130001     56242.4367867 ... 0.5487189116713084 0.020269622978450114
# 44508746095665     56241.5245967 ... 0.5451458348415311  0.24859862991297635

# %%
match.approved['var_Stetson_JHK']
# Out:
# <MaskedColumn name='var_Stetson_JHK' dtype='float64' length=387>
#   2.2353222779553343
#   0.9073756426230244
#       0.941162109375
#   23.204067887931036
#     4.74023577810704
#  0.36202386878002646
# -0.10960409376356336
#    8.795645480685764
#   0.9124534924825032
#   0.8101268181434045
#   0.4822243876840876
#   14.745494106359647
#   13.911473767510774
#    0.753202342023753
#  0.33047020572355423
#   0.6529056279346196
#   0.9109682569316788
#    0.675539353314568
#                  ...
#   1.3629024212176983
#    1.931639546095723
#  0.07295299298835523
#   0.9197611490885416
#  0.34669210260564626
#   0.5737444174410117
#    6.019870087594697
#   3.5553267045454544
#    2.573904018209438
#   2.4921545163549554
#  0.31053353398224043
#    4.307031702112268
#   1.1983503861860796
#    2.404534172289299
#    2.195543693773674
#   0.8983116869656544
#   24.193284377553102

# %%
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_v/s9cr1q_d6kj1m6f7d08s0_cr0000gn/T/ipykernel_36228/2369097233.py in <module>
# ----> 1 ds
#
# NameError: name 'ds' is not defined

# %%
np.in1d(match.approved['SOURCEID'], v_per.index)
# Out:
# array([False, False, False, False,  True, False, False, False, False,
#        False, False, False,  True, False, False, False, False,  True,
#        False, False,  True, False, False, False, False, False,  True,
#        False, False, False, False,  True,  True, False, False,  True,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False,  True,  True,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False,  True, False, False,  True, False,
#        False,  True, False, False, False, False,  True,  True, False,
#         True,  True,  True,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False,  True,
#        False, False, False,  True, False, False,  True, False, False,
#         True,  True, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False])

# %%
v_per.index
# Out:
# Int64Index([44508746098719, 44508746128322, 44508746098403, 44508746098400,
#             44508746107325, 44508746107378, 44508746116168, 44508746116177,
#             44508746116243, 44508746116314, 44508746116316, 44508746116558,
#             44508746116731, 44508746117253, 44508746116800, 44508746116840,
#             44508746117257, 44508746116914, 44508746116949, 44508746116989,
#             44508746116994, 44508746116999, 44508746117406, 44508746117427,
#             44508746107212, 44508746117537, 44508746117569, 44508746117584,
#             44508746117684],
#            dtype='int64', name='SOURCEID')

# %%
periodics = np.in1d(match.approved['SOURCEID'], v_per.index)

# %%
match.approved['SOURCEID'][periodics]
# Out:
# <Column name='SOURCEID' dtype='int64' length=29>
# 44508746098719
# 44508746128322
# 44508746098403
# 44508746098400
# 44508746107325
# 44508746107378
# 44508746116168
# 44508746116177
# 44508746116243
# 44508746116314
# 44508746116316
# 44508746116558
# 44508746116731
# 44508746117253
# 44508746116800
# 44508746116840
# 44508746117257
# 44508746116914
# 44508746116949
# 44508746116989
# 44508746116994
# 44508746116999
# 44508746117406
# 44508746117427
# 44508746107212
# 44508746117537
# 44508746117569
# 44508746117584
# 44508746117684

# %%
v_per
# Out:
#                 index           shortname  ...       Amp  Color? (dK/dJ)
# SOURCEID                                   ...
# 44508746098719      3    ngc_003A_M8.0_Q0  ...  0.014748        0.703554
# 44508746128322      8  ngc_008S_M9.0_Q1HK  ...  0.059975             NaN
# 44508746098403     12    ngc_012C_M8.2_Q2  ...  0.021838        1.060816
# 44508746098400     14  ngc_014A_M6.5_Q1JH  ...  0.049800        0.531890
# 44508746107325     19    ngc_019C_M7.5_Q2  ...  0.025821             NaN
# 44508746107378     22    ngc_022C_M8.2_Q2  ...  0.013737        0.791245
# 44508746116168     23   ngc_023A_M6.0_Q1J  ...  0.012353             NaN
# 44508746116177     24    ngc_024C_M6.5_Q2  ...  0.011626        0.813566
# 44508746116243     28    ngc_028C_M6.5_Q2  ...  0.007455             NaN
# 44508746116314     34    ngc_034A_M8.0_Q0  ...  0.064903             NaN
# 44508746116316     35    ngc_035C_M5.5_Q2  ...  0.008009        0.783300
# 44508746116558     41    ngc_041C_M8.2_Q2  ...  0.025146             NaN
# 44508746116731     55    ngc_055C_M7.8_Q2  ...  0.036622             NaN
# 44508746117253     57    ngc_057A_M6.0_Q0  ...  0.035795        0.777828
# 44508746116800     60    ngc_060C_M5.5_Q2  ...  0.095736             NaN
# 44508746116840     63    ngc_063C_M5.0_Q2  ...  0.028422        0.821787
# 44508746117257     67    ngc_067C_M8.0_Q2  ...  0.020041        0.761643
# 44508746116914     68    ngc_068C_M4.5_Q2  ...  0.012000        1.200000
# 44508746116949     70    ngc_070C_M9.0_Q2  ...  0.022168             NaN
# 44508746116989     71    ngc_071C_M6.2_Q2  ...  0.018701        0.958169
# 44508746116994     72    ngc_072C_M5.2_Q2  ...  0.012000             NaN
# 44508746116999     73    ngc_073C_M7.5_Q2  ...  0.008821             NaN
# 44508746117406     82    ngc_082C_M4.8_Q2  ...  0.045303        0.650461
# 44508746117427     85    ngc_085C_M5.5_Q2  ...  0.007435             NaN
# 44508746107212     88    ngc_088C_M7.5_Q2  ...  0.041032        0.917502
# 44508746117537     90    ngc_090C_M4.5_Q2  ...  0.016425             NaN
# 44508746117569     92    ngc_092C_M5.5_Q2  ...  0.086886        0.741920
# 44508746117584     93    ngc_093C_M4.5_Q2  ...  0.167475        0.465149
# 44508746117684     99    ngc_099C_M6.8_Q2  ...  0.012147        0.712046
#
# [29 rows x 27 columns]

# %%
match.approved.columns
# Out:
# <TableColumns names=('SOURCEID','median_MEANMJDOBS','median_RA','median_DEC','median_JMHPNT','median_JMHPNTERR','median_HMKPNT','median_HMKPNTERR','median_JAPERMAG3','median_JAPERMAG3ERR','median_HAPERMAG3','median_HAPERMAG3ERR','median_KAPERMAG3','median_KAPERMAG3ERR','median_JPPERRBITS','median_HPPERRBITS','median_KPPERRBITS','median_MERGEDCLASS','median_PSTAR','median_JGRADE','median_HGRADE','median_KGRADE','var_J_red_chisq','var_H_red_chisq','var_K_red_chisq','var_Stetson_HK','var_Stetson_JK','var_Stetson_JH','var_Stetson_JHK','std_MEANMJDOBS','std_RA','std_DEC','std_JMHPNT','std_JMHPNTERR','std_HMKPNT','std_HMKPNTERR','std_JAPERMAG3','std_JAPERMAG3ERR','std_HAPERMAG3','std_HAPERMAG3ERR','std_KAPERMAG3','std_KAPERMAG3ERR','std_JPPERRBITS','std_HPPERRBITS','std_KPPERRBITS','std_MERGEDCLASS','std_PSTAR','std_JGRADE','std_HGRADE','std_KGRADE','range_MEANMJDOBS','range_RA','range_DEC','range_JMHPNT','range_JMHPNTERR','range_HMKPNT','range_HMKPNTERR','range_JAPERMAG3','range_JAPERMAG3ERR','range_HAPERMAG3','range_HAPERMAG3ERR','range_KAPERMAG3','range_KAPERMAG3ERR','range_JPPERRBITS','range_HPPERRBITS','range_KPPERRBITS','range_MERGEDCLASS','range_PSTAR','range_JGRADE','range_HGRADE','range_KGRADE','Name','RAh','RAm','RAs','DE-','DEd','DEm','DEs','Luhman','Evans','Stelzer','AlvesdeOliveira','OtherNames','SpType','r_SpType','Spectrograph','Date','Adopt','Aj','IRexc','pmRA','e_pmRA','pmDE','e_pmDE','Jmag','e_Jmag','Hmag','e_Hmag','Ksmag','e_Ksmag','JHKref','SpT','Teff','RA','DEC','d2d_arcsec')>
