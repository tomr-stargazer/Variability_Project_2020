# %%
# %run ../stetson_vs_mag.py

# %%
np.vstack([x_grid, result_grid_997])
# Out:
# array([[11.        , 11.1       , 11.2       , 11.3       , 11.4       ,
#         11.5       , 11.6       , 11.7       , 11.8       , 11.9       ,
#         12.        , 12.1       , 12.2       , 12.3       , 12.4       ,
#         12.5       , 12.6       , 12.7       , 12.8       , 12.9       ,
#         13.        , 13.1       , 13.2       , 13.3       , 13.4       ,
#         13.5       , 13.6       , 13.7       , 13.8       , 13.9       ,
#         14.        , 14.1       , 14.2       , 14.3       , 14.4       ,
#         14.5       , 14.6       , 14.7       , 14.8       , 14.9       ,
#         15.        , 15.1       , 15.2       , 15.3       , 15.4       ,
#         15.5       , 15.6       , 15.7       , 15.8       , 15.9       ,
#         16.        , 16.1       , 16.2       , 16.3       , 16.4       ,
#         16.5       , 16.6       , 16.7       , 16.8       , 16.9       ,
#         17.        , 17.1       , 17.2       , 17.3       , 17.4       ,
#         17.5       , 17.6       , 17.7       , 17.8       , 17.9       ],
#        [ 1.71373306,  1.70759749,  1.70452971,  1.69839414,  1.69839414,
#          1.69839414,  1.69839414,  1.69839414,  1.69839414,  1.69839414,
#          1.69839414,  1.69839414,  1.69839414,  1.69839414,  1.69839414,
#          1.69839414,  1.69839414,  1.69839414,  1.69839414,  1.62352685,
#          1.60459155,  1.38761527,  1.32059297,  1.31930455,  1.31930455,
#          1.31162055,  1.31162055,  1.31162055,  1.31162055,  1.31162055,
#          1.31162055,  1.31162055,  1.28486026,  1.27230292,  1.2593868 ,
#          1.24539434,  1.23176066,  1.22135601,  1.22135601,  1.20364778,
#          1.19548772,  1.1003436 ,  1.07414728,  1.05422332,  1.0387269 ,
#          1.0387269 ,  1.0387269 ,  0.79052652,  0.75748191,  0.72644001,
#          0.7007153 ,  0.67871762,  0.62525344,  0.55098262,  0.550375  ,
#          0.51949926,  0.44613494,  0.44095343,  0.43494282,  0.43494282,
#          0.43494282,  0.43494282,  0.43494282,  0.43494282,  0.43494282,
#          0.43494282,  0.42811393,  0.42811393,  0.42811393,  0.42584563]])

# %%
np.save?

# %%
load_dir = "/Users/tsrice/Documents/Variability_Project_2020/wuvars/analysis/stetson_v_mag"

for wserv in [5, 7, 8]:
    r997 = np.load(
        os.path.join(load_dir, f"WSERV{wserv}_result_grid_997.npy"),
    )
    r95 = np.load(
        os.path.join(load_dir, f"WSERV{wserv}_result_grid_95.npy"),
    )
    r50 = np.load(
        os.path.join(load_dir, f"WSERV{wserv}_result_grid_50.npy"),
    )
    
    plt.plot(r997[0], r997[1], f'C0-')
    plt.plot(r95[0], r95[1], f'C1-')
    plt.plot(r50[0], r50[1], f'C2-')
    
    plt.xlim(None, 17)
    plt.semilogy()

# %%
np.interp?
