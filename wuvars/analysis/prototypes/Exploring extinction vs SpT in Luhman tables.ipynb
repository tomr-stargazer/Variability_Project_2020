# %% [markdown]
# # The idea
# How much extinction is in the Luhman tables?

# %%
# %run ../bd_matching_ic348.py
L16_M4s = np.array(L16_SpT_num) >= 4.0
L16_M6s = np.array(L16_SpT_num) >= 6.0
L16_M8s = np.array(L16_SpT_num) >= 8.0
plt.hist(1/0.28 * L16_T1['Aj'][L16_M4s], bins=20, range=[0,40], label='M4 $-$ M5.5')
plt.hist(1/0.28 * L16_T1['Aj'][L16_M6s], bins=20, range=[0,40], label='M6 $-$ M7.5')
plt.hist(1/0.28 * L16_T1['Aj'][L16_M8s], bins=20, range=[0,40], label=r'$\geq$ M8')
plt.xlabel("$A_{V}$ (mag)", fontsize=18)
plt.ylabel("N", fontsize=18, rotation='horizontal')
plt.title("Histogram of extinction ($A_V$)\namong $\\geq$M4 objects in IC 348", fontsize=18)
plt.legend(fontsize=18)

# %%
plt.hist(L16_SpT_num, range=[4, 20], bins=16*2)
plt.xlabel("SpT number (M0=0, L0=10)", fontsize=18)
# Out:
# Text(0.5, 0, 'SpT number (M0=0, L0=10)')

# %%
plt.hist(L16_T1['Aj'])
# Out:
# (array([254., 131.,  49.,  22.,  12.,   3.,   2.,   0.,   3.,   2.]),
#  array([0.  , 0.79, 1.58, 2.37, 3.16, 3.95, 4.74, 5.53, 6.32, 7.11, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
# %run ../bd_matching_ngc1333.py
L16_M4s = np.array(L16_SpT_num) >= 4.0
L16_M6s = np.array(L16_SpT_num) >= 6.0

plt.hist(1/0.28 * L16_T2['Aj'][L16_M4s], bins=20, range=[0,40], label='M4 $-$ M5.5')
plt.hist(1/0.28 * L16_T2['Aj'][L16_M6s], bins=20, range=[0,40], label=r'$\geq$ M6')
plt.xlabel("$A_{V}$ (mag)", fontsize=18)
plt.ylabel("N", fontsize=18, rotation='horizontal')
plt.title("Histogram of extinction ($A_V$)\namong $\\geq$M4 objects in NGC 1333", fontsize=18)
plt.legend(fontsize=18)

# %%
plt.hist(L16_SpT_num, range=[4, 20], bins=16*2)
plt.xlabel("SpT number (M0=0, L0=10)", fontsize=18)
# Out:
# Text(0.5, 0, 'SpT number (M0=0, L0=10)')
