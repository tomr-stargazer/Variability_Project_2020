# %%
# %run ../legacy_cleaning.py

# %%
make()
# Out:
# Input:  /Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/Raw_Downloads/wserv1.fits.gz
# Output:  /Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/reduction_artifacts/wserv1/
# Name:  WSERV1
# Auto-detected table type: fits
# Auto-detected table type: hdf5
# /Users/tsrice/opt/anaconda3/lib/python3.7/site-packages/atpy/decorators.py:56: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/reduction_artifacts/wserv1/summary_spreadsheet.h5'>
#   header = open(filename, 'rb').read(4)
# 560  timestamps in this dataset
# For night 53937.38396:
# 0 0
# For night 53937.38722:
# 0 0
# For night 53937.3905:
# 0 0
# For night 53937.39383:
# 0 0
# For night 53937.456825:
# 1509 1509
# For night 53937.46217:
# 1991 1991
# For night 53937.46753:
# 1837 1837
# For night 53937.472925:
# 2053 2053
# For night 53942.46915:
# 0 0
# For night 53942.48078:
# 0 0
# For night 53942.49208:
# 0 0
# For night 53942.50387:
# ...

# %%
from wuvars.reduction.legacy_cleaning_helpers import spreadsheet_mapreduce_combine
from wuvars.reduction.legacy_cleaning_helpers import spreadsheet_combine

# %%
# my code crashed overnight, so I had to manually glue together the relevant spreadsheet

splits = 100
glue_start=0
intermediate_location = "/Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/reduction_artifacts/wserv1/intermediate/"

summary_spreadsheet = spreadsheet_combine(intermediate_location, splits=splits, start=glue_start)
# Out:
# Auto-detected table type: hdf5
# /Users/tsrice/opt/anaconda3/lib/python3.7/site-packages/atpy/decorators.py:56: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/reduction_artifacts/wserv1/intermediate/sp0.h5'>
#   header = open(filename, 'rb').read(4)
# /Users/tsrice/opt/anaconda3/lib/python3.7/importlib/__init__.py:127: H5pyDeprecationWarning: The h5py.highlevel module is deprecated, code should import directly from h5py, e.g. 'from h5py import File'.
#   return _bootstrap._gcd_import(name[level:], package, level)
# Auto-detected table type: hdf5
# /Users/tsrice/opt/anaconda3/lib/python3.7/site-packages/atpy/decorators.py:56: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/reduction_artifacts/wserv1/intermediate/sp1.h5'>
#   header = open(filename, 'rb').read(4)
# Auto-detected table type: hdf5
# ...

# %%
summary_spreadsheet
# Out:
# <Table name='spreadsheet' rows=227368 fields=153>

# %%
wserv1_output_path = "/Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/reduction_artifacts/wserv1/"
summary_spreadsheet.write(
    os.path.join(wserv1_output_path, "summary_spreadsheet.h5"), overwrite=True
)
# Out:
# Auto-detected table type: hdf5

# %%
# %run ../legacy_cleaning.py

# %%
generate_wserv5_trimmed_by_RA()
# Out:
# WARNING: UnitsWarning: 'RADIANS' did not parse as fits unit: At col 0, Unit 'RADIANS' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see http://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]

# %%
make_wserv5_only()
# Out:
# Input:  /Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/reduction_artifacts/wserv5/wserv5_spatially_trimmed.fits
# Output:  /Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/reduction_artifacts/wserv5/
# Name:  WSERV5_trimmed
# Auto-detected table type: fits
# Auto-detected table type: hdf5
# Auto-detected table type: hdf5
# Wrote output to /Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/reduction_artifacts/wserv5/intermediate/sp0.h5
# finished chunk 0 at 2020-10-22 16:06:17
# Auto-detected table type: hdf5
# Wrote output to /Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/reduction_artifacts/wserv5/intermediate/sp1.h5
# finished chunk 1 at 2020-10-22 16:07:54
# Auto-detected table type: hdf5
# Wrote output to /Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/reduction_artifacts/wserv5/intermediate/sp2.h5
# finished chunk 2 at 2020-10-22 16:10:13
# Auto-detected table type: hdf5
# ...
