# %%
filepath = "/Users/tsrice/Documents/Variability_Project_2020/wuvars/Data/Raw_Downloads"

# %%
import astropy.table as tab
import os
from astropy.io.fits import getdata, getheader

# %%
table = tab.Table.read(os.path.join(filepath,"wserv11.fits.gz"))
data, header = getdata(os.path.join(filepath,"wserv11.fits.gz"), header=True)

# %%
header
# Out:
# XTENSION= 'BINTABLE'           /  Java FITS: Mon Jul 06 21:27:21 BST 2020
# BITPIX  =                    8
# NAXIS   =                    2 / Dimensionality
# NAXIS1  =                   90
# NAXIS2  =              2989616 /
# PCOUNT  =                    0
# GCOUNT  =                    1
# TFIELDS =                   19
# SYMBOL  = '{} cross 5'
# DATABASE= 'WSERV11v20180903'   /  database release version
# DATE    = '2020-07-06T20:27:21' /  UTC datetime of file creation
# COMMENT FITSWriter: database:WSERV11v20180903
# COMMENT 06/07/20 21:27
# COMMENT SQL Query
# COMMENT select SOURCEID, MEANMJDOBS, s.RA, s.DEC, JMHPNT, JMHPNTERR, HMKPNT,
# COMMENT HMKPNTERR, JAPERMAG3, JAPERMAG3ERR, HAPERMAG3, HAPERMAG3ERR,
# COMMENT KAPERMAG3, KAPERMAG3ERR, JPPERRBITS, HPPERRBITS, KPPERRBITS,
# COMMENT MERGEDCLASS, PSTAR from
# COMMENT wserv11SourceXSynopticSourceBestMatch as b, wserv11SynopticMergeLog
# COMMENT as l, wserv11SynopticSource as s  where
# ...
