# %%
# %run ../ic348_matches_latex.py

# %%
bd_results_table
# Out:
# <Table length=81>
#           Name             SOURCEID    ...     KAPERMAG3ERR      SpT
#          str28              int64      ...       float64         str5
# ----------------------- -------------- ... -------------------- -----
#   IRS J03432251+3218174 44989782463184 ...  0.05668340250849724    L0
# 2MASS J03433137+3200198 44989782489794 ... 0.013761060312390327  M7.5
#   IRS J03434240+3209329 44989782469858 ... 0.025659415870904922 M9.75
#   IRS J03434535+3155257 44989782427133 ...   0.0158875472843647  M6.5
# 2MASS J03434763+3209025 44989782469715 ... 0.009376139380037785 M7.25
# 2MASS J03435056+3203180 44989782469609 ... 0.014199304394423962    M9
# 2MASS J03435508+3207145 44989782469417 ... 0.008948217146098614    M6
#   IRS J03435616+3203061 44989782469347 ...  0.02114253304898739    M8
# 2MASS J03435638+3209591 44989782469336 ... 0.010090868920087814 M7.25
# 2MASS J03435721+3201337 44989782469473 ... 0.008983304724097252 M6.75
#                     ...            ... ...                  ...   ...
#   IRS J03450417+3206031 44989782496169 ...  0.05379942059516907    M9
# 2MASS J03450644+3159394 44989782497399 ... 0.010258534923195839  M6.5
#   IRS J03450885+3215471 44989782457693 ...  0.03415798768401146    L0
# 2MASS J03451212+3209131 44989782495272 ... 0.008953099139034748    M6
#   IRS J03451284+3203362 44989782496728 ... 0.039699770510196686    M9
#   IRS J03451765+3207553 44989782495656 ...   0.0376322902739048    L0
# 2MASS J03452212+3205450 44989782496268 ...  0.01587877981364727    M8
# 2MASS J03452390+3211544 44989782494562 ... 0.009991551749408245    M6
# 2MASS J03453146+3212290 44989782494425 ... 0.016558010131120682  M6.5
# 2MASS J03454360+3212317 44989782474172 ... 0.011663312092423439  M6.5

# %%
coords = SkyCoord(
    ra=bd_results_table["RA"] * u.rad, dec=bd_results_table ["DEC"] * u.rad
)

# %%
coords
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(55.84381049, 32.30485042), (55.88075632, 32.0055021 ),
#      (55.92671338, 32.1590777 ), (55.93897802, 31.92385595),
#      (55.94849613, 32.15068705), (55.96077177, 32.05488117),
#      (55.97954714, 32.12069165), (55.9840007 , 32.05173526),
#      (55.98494414, 32.16644046), (55.98842731, 32.02603662),
#      (55.98976274, 32.24690696), (56.00313294, 32.07222427),
#      (56.01216584, 31.87435452), (56.0249736 , 32.25893398),
#      (56.0302744 , 32.2425453 ), (56.04610634, 32.02878553),
#      (56.04700018, 32.34741256), (56.0479463 , 32.302666  ),
#      (56.06214838, 32.22872436), (56.06446262, 32.32309174),
#      (56.06489418, 32.1560511 ), (56.06743569, 32.09472083),
#      (56.07192395, 32.00424563), (56.0753506 , 31.94999   ),
#      (56.07728534, 32.28330794), (56.07816096, 32.19223675),
#      (56.07854987, 32.32579267), (56.07924908, 32.36824956),
#      (56.0819127 , 32.11275303), (56.08812358, 32.10462597),
#      (56.10748036, 32.18302186), (56.10804287, 32.13482688),
#      (56.11201008, 32.15725519), (56.11212883, 32.2140411 ),
#      (56.11325951, 32.06295162), (56.11449369, 32.10673984),
#      (56.12418695, 32.01516492), (56.12460618, 32.32252408),
#      (56.12487249, 32.16095721), (56.12524053, 32.14692741),
#      (56.1264755 , 32.16239247), (56.13060036, 32.13652249),
#      (56.13926949, 32.17543612), (56.14036501, 32.09634951),
#      (56.14035606, 32.08905701), (56.14186157, 32.11584693),
#      (56.14392213, 32.03714909), (56.14542788, 32.25001727),
#      (56.14974742, 32.18819338), (56.15101693, 32.21791445),
#      (56.15157266, 32.05151988), (56.15256177, 32.06231418),
#      (56.15323228, 32.39130021), (56.15893271, 32.17264822),
#      (56.16194738, 32.11011151), (56.16335575, 32.13713995),
#      (56.16365852, 32.24526259), (56.17374645, 32.29856299),
#      (56.20554901, 32.16373396), (56.20937021, 32.10986935),
#      (56.21051171, 31.94923581), (56.21451562, 32.33168712),
#      (56.2166728 , 31.98933532), (56.2370832 , 32.3432288 ),
#      (56.23892491, 32.14307393), (56.24050574, 32.12823745),
#      (56.24317061, 32.30324934), (56.24397065, 31.97416803),
#      (56.26506404, 32.20383307), (56.26575978, 32.35957892),
#      (56.26720965, 32.08457995), (56.26741619, 32.10079354),
#      (56.27685551, 31.9943023 ), (56.28695675, 32.26301911),
#      (56.30053247, 32.1536486 ), (56.30353279, 32.06001219),
#      (56.32353112, 32.13203208), (56.34229544, 32.09587958),
#      (56.3495397 , 32.1984674 ), (56.3810061 , 32.20800404),
#      (56.43168499, 32.20882302)]>

# %%
latex_strings = []

for i, row in enumerate(bd_results_table):
#     latex_items = []
    
    name = row['Name']
    ra = coords[i].ra.to_string(sep=" ", unit=u.hourangle, precision=2, pad=True)
    dec = coords[i].dec.to_string(sep=" ", precision=1, alwayssign=True)
    
    j = row['JAPERMAG3']
    h = row['HAPERMAG3']
    k = row['KAPERMAG3']
    j_e = row['JAPERMAG3ERR']
    h_e = row['HAPERMAG3ERR']
    k_e = row['KAPERMAG3ERR']    
    
    j_pm = f"{j:.2f} $\pm$ {j_e:.2f}"
    h_pm = f"{h:.2f} $\pm$ {h_e:.2f}"
    k_pm = f"{k:.2f} $\pm$ {k_e:.2f}"
    
    SpT = row['SpT']
    
    ref = '1'
    
    latex_items = [name, ra, dec, j_pm, h_pm, k_pm, SpT, ref]
    
    latex_row_string = ' & '.join(latex_items)+r' \\'
    
    print(latex_row_string)
# Out:
# IRS J03432251+3218174 & 03 43 22.51 & +32 18 17.5 & 18.56 $\pm$ 0.09 & 17.69 $\pm$ 0.07 & 16.84 $\pm$ 0.06 & L0 & 1 \\
# 2MASS J03433137+3200198 & 03 43 31.38 & +32 00 19.8 & 16.30 $\pm$ 0.02 & 15.58 $\pm$ 0.01 & 14.99 $\pm$ 0.01 & M7.5 & 1 \\
# IRS J03434240+3209329 & 03 43 42.41 & +32 09 32.7 & 18.33 $\pm$ 0.07 & 17.08 $\pm$ 0.04 & 15.97 $\pm$ 0.03 & M9.75 & 1 \\
# IRS J03434535+3155257 & 03 43 45.35 & +31 55 25.9 & 16.42 $\pm$ 0.02 & 15.80 $\pm$ 0.02 & 15.26 $\pm$ 0.02 & M6.5 & 1 \\
# 2MASS J03434763+3209025 & 03 43 47.64 & +32 09 02.5 & 14.71 $\pm$ 0.01 & 14.12 $\pm$ 0.01 & 13.59 $\pm$ 0.01 & M7.25 & 1 \\
# 2MASS J03435056+3203180 & 03 43 50.59 & +32 03 17.6 & 17.69 $\pm$ 0.04 & 16.33 $\pm$ 0.02 & 15.06 $\pm$ 0.01 & M9 & 1 \\
# 2MASS J03435508+3207145 & 03 43 55.09 & +32 07 14.5 & 14.13 $\pm$ 0.01 & 13.53 $\pm$ 0.01 & 13.01 $\pm$ 0.01 & M6 & 1 \\
# IRS J03435616+3203061 & 03 43 56.16 & +32 03 06.2 & 19.59 $\pm$ 0.18 & 17.52 $\pm$ 0.05 & 15.71 $\pm$ 0.02 & M8 & 1 \\
# 2MASS J03435638+3209591 & 03 43 56.39 & +32 09 59.2 & 15.42 $\pm$ 0.01 & 14.69 $\pm$ 0.01 & 14.07 $\pm$ 0.01 & M7.25 & 1 \\
# 2MASS J03435721+3201337 & 03 43 57.22 & +32 01 33.7 & 15.62 $\pm$ 0.01 & 14.21 $\pm$ 0.01 & 13.07 $\pm$ 0.01 & M6.75 & 1 \\
# 2MASS J03435754+3214488 & 03 43 57.54 & +32 14 48.9 & 14.94 $\pm$ 0.01 & 14.30 $\pm$ 0.01 & 13.78 $\pm$ 0.01 & M6 & 1 \\
# IRS J03440077+3204199 & 03 44 00.75 & +32 04 20.0 & 19.31 $\pm$ 0.16 & 18.47 $\pm$ 0.13 & 17.69 $\pm$ 0.11 & L0 & 1 \\
# IRS J03440294+3152280 & 03 44 02.92 & +31 52 27.7 & 14.51 $\pm$ 0.01 & 13.58 $\pm$ 0.01 & 12.86 $\pm$ 0.01 & M6 & 1 \\
# 2MASS J03440599+3215321 & 03 44 05.99 & +32 15 32.2 & 14.33 $\pm$ 0.01 & 13.79 $\pm$ 0.01 & 13.30 $\pm$ 0.01 & M6.5 & 1 \\
# IRS J03440727+3214334 & 03 44 07.27 & +32 14 33.2 & 17.81 $\pm$ 0.05 & 16.88 $\pm$ 0.03 & 16.06 $\pm$ 0.03 & M9 & 1 \\
# 2MASS J03441106+3201436 & 03 44 11.07 & +32 01 43.6 & 16.56 $\pm$ 0.02 & 15.47 $\pm$ 0.01 & 14.42 $\pm$ 0.01 & M8.25 & 1 \\
# 2MASS J03441127+3220508 & 03 44 11.28 & +32 20 50.7 & 15.86 $\pm$ 0.01 & 15.16 $\pm$ 0.01 & 14.62 $\pm$ 0.01 & M6 & 1 \\
# 2MASS J03441150+3218094 & 03 44 11.51 & +32 18 09.6 & 15.87 $\pm$ 0.01 & 15.09 $\pm$ 0.01 & 14.41 $\pm$ 0.01 & M8.25 & 1 \\
# IRS J03441492+3213435 & 03 44 14.92 & +32 13 43.4 & 18.13 $\pm$ 0.07 & 17.20 $\pm$ 0.05 & 16.35 $\pm$ 0.04 & M9 & 1 \\
# IRS J03441547+3219230 & 03 44 15.47 & +32 19 23.1 & 17.79 $\pm$ 0.05 & 16.85 $\pm$ 0.03 & 16.04 $\pm$ 0.03 & M9 & 1 \\
# 2MASS J03441558+3209218 & 03 44 15.57 & +32 09 21.8 & 14.57 $\pm$ 0.01 & 13.92 $\pm$ 0.01 & 13.34 $\pm$ 0.01 & M7.5 & 1 \\
# IRS J03441618+3205410 & 03 44 16.18 & +32 05 41.0 & 17.73 $\pm$ 0.04 & 16.87 $\pm$ 0.03 & 16.07 $\pm$ 0.03 & M9 & 1 \\
# 2MASS J03441726+3200152 & 03 44 17.26 & +32 00 15.3 & 14.93 $\pm$ 0.01 & 14.31 $\pm$ 0.01 & 13.72 $\pm$ 0.01 & M8 & 1 \\
# 2MASS J03441807+3156599 & 03 44 18.08 & +31 57 00.0 & 15.38 $\pm$ 0.01 & 14.64 $\pm$ 0.01 & 14.08 $\pm$ 0.01 & M6 & 1 \\
# IRS J03441855+3217000 & 03 44 18.55 & +32 17 00.0 & 14.92 $\pm$ 0.01 & 14.38 $\pm$ 0.01 & 13.88 $\pm$ 0.01 & M7.5 & 1 \\
# IRS J03441876+3211321 & 03 44 18.76 & +32 11 32.1 & 18.00 $\pm$ 0.05 & 17.18 $\pm$ 0.04 & 16.42 $\pm$ 0.04 & M9 & 1 \\
# IRS J03441885+3219327 & 03 44 18.85 & +32 19 32.9 & 16.82 $\pm$ 0.02 & 16.03 $\pm$ 0.02 & 15.35 $\pm$ 0.02 & M8.25 & 1 \\
# 2MASS J03441901+3222057 & 03 44 19.02 & +32 22 05.7 & 14.49 $\pm$ 0.01 & 13.81 $\pm$ 0.01 & 13.25 $\pm$ 0.01 & M6.75 & 1 \\
# IRS J03441967+3206459 & 03 44 19.66 & +32 06 45.9 & -- $\pm$ -- & -- $\pm$ -- & -- $\pm$ -- & M7 & 1 \\
# IRS J03442116+3206166 & 03 44 21.15 & +32 06 16.7 & 15.16 $\pm$ 0.01 & 14.51 $\pm$ 0.01 & 13.89 $\pm$ 0.01 & M8 & 1 \\
# 2MASS J03442581+3210588 & 03 44 25.80 & +32 10 58.9 & 17.27 $\pm$ 0.03 & 15.71 $\pm$ 0.01 & 14.63 $\pm$ 0.01 & M6 & 1 \\
# IRS J03442593+3208054 & 03 44 25.93 & +32 08 05.4 & 19.29 $\pm$ 0.15 & 18.37 $\pm$ 0.11 & 17.46 $\pm$ 0.09 & L1 & 1 \\
# 2MASS J03442685+3209257 & 03 44 26.88 & +32 09 26.1 & 16.69 $\pm$ 0.02 & 16.06 $\pm$ 0.02 & 15.44 $\pm$ 0.02 & M8.25 & 1 \\
# 2MASS J03442691+3212506 & 03 44 26.91 & +32 12 50.5 & 16.38 $\pm$ 0.02 & 15.73 $\pm$ 0.02 & 15.12 $\pm$ 0.02 & M8.25 & 1 \\
# IRS J03442717+3203466 & 03 44 27.18 & +32 03 46.6 & 17.17 $\pm$ 0.03 & 16.38 $\pm$ 0.02 & 15.65 $\pm$ 0.02 & M9 & 1 \\
# IRS J03442747+3206241 & 03 44 27.48 & +32 06 24.3 & 19.46 $\pm$ 0.21 & 19.12 $\pm$ 0.20 & 18.17 $\pm$ 0.17 & L1 & 1 \\
# 2MASS J03442980+3200545 & 03 44 29.80 & +32 00 54.6 & 13.63 $\pm$ 0.01 & 12.94 $\pm$ 0.01 & 12.33 $\pm$ 0.01 & M6 & 1 \\
# IRS J03442990+3219210 & 03 44 29.91 & +32 19 21.1 & 15.05 $\pm$ 0.01 & 14.32 $\pm$ 0.01 & 13.68 $\pm$ 0.01 & M8.25 & 1 \\
# 2MASS J03442997+3209394 & 03 44 29.97 & +32 09 39.4 & 15.10 $\pm$ 0.01 & 14.36 $\pm$ 0.01 & 13.66 $\pm$ 0.01 & M6.5 & 1 \\
# 2MASS J03443005+3208489 & 03 44 30.06 & +32 08 48.9 & 14.59 $\pm$ 0.01 & 13.81 $\pm$ 0.01 & 13.16 $\pm$ 0.01 & M6 & 1 \\
# 2MASS J03443035+3209446 & 03 44 30.35 & +32 09 44.6 & -- $\pm$ -- & -- $\pm$ -- & -- $\pm$ -- & M8 & 1 \\
# IRS J03443133+3208114 & 03 44 31.34 & +32 08 11.5 & 17.44 $\pm$ 0.03 & 16.82 $\pm$ 0.03 & 16.18 $\pm$ 0.03 & M6 & 1 \\
# 2MASS J03443341+3210314 & 03 44 33.42 & +32 10 31.6 & 16.57 $\pm$ 0.02 & 15.75 $\pm$ 0.01 & 14.98 $\pm$ 0.01 & M8.5 & 1 \\
# IRS J03443369+3205467 & 03 44 33.69 & +32 05 46.9 & 17.44 $\pm$ 0.03 & 16.72 $\pm$ 0.03 & 16.02 $\pm$ 0.03 & M8.75 & 1 \\
# IRS J03443370+3205207 & 03 44 33.69 & +32 05 20.6 & 18.04 $\pm$ 0.05 & 17.38 $\pm$ 0.05 & 16.89 $\pm$ 0.05 & M6 & 1 \\
# IRS J03443405+3206569 & 03 44 34.05 & +32 06 57.0 & 14.01 $\pm$ 0.01 & 13.33 $\pm$ 0.01 & 12.72 $\pm$ 0.01 & M7.25 & 1 \\
# IRS J03443454+3202138 & 03 44 34.54 & +32 02 13.7 & 19.32 $\pm$ 0.15 & 18.31 $\pm$ 0.11 & 17.39 $\pm$ 0.09 & L1 & 1 \\
# 2MASS J03443487+3215002 & 03 44 34.90 & +32 15 00.1 & 17.00 $\pm$ 0.03 & 16.22 $\pm$ 0.02 & 15.54 $\pm$ 0.02 & M7.5 & 1 \\
# 2MASS J03443593+3211175 & 03 44 35.94 & +32 11 17.5 & 15.73 $\pm$ 0.01 & 15.06 $\pm$ 0.01 & 14.50 $\pm$ 0.01 & M6.25 & 1 \\
# 2MASS J03443624+3213041 & 03 44 36.24 & +32 13 04.5 & 17.17 $\pm$ 0.03 & 15.85 $\pm$ 0.02 & 14.94 $\pm$ 0.01 & M6 & 1 \\
# 2MASS J03443638+3203054 & 03 44 36.38 & +32 03 05.5 & 16.61 $\pm$ 0.02 & 15.90 $\pm$ 0.02 & 15.21 $\pm$ 0.02 & M8.75 & 1 \\
# 2MASS J03443661+3203442 & 03 44 36.61 & +32 03 44.3 & 16.56 $\pm$ 0.02 & 15.74 $\pm$ 0.01 & 15.01 $\pm$ 0.01 & M8 & 1 \\
# IRS J03443678+3223285 & 03 44 36.78 & +32 23 28.7 & 13.98 $\pm$ 0.01 & 13.27 $\pm$ 0.01 & 12.74 $\pm$ 0.01 & M6 & 1 \\
# 2MASS J03443814+3210215 & 03 44 38.14 & +32 10 21.5 & 14.34 $\pm$ 0.01 & 13.68 $\pm$ 0.01 & 13.22 $\pm$ 0.01 & M6 & 1 \\
# 2MASS J03443886+3206364 & 03 44 38.87 & +32 06 36.4 & 13.95 $\pm$ 0.01 & 13.30 $\pm$ 0.01 & 12.82 $\pm$ 0.01 & M6 & 1 \\
# 2MASS J03443920+3208136 & 03 44 39.21 & +32 08 13.7 & 14.81 $\pm$ 0.01 & 14.06 $\pm$ 0.01 & 13.45 $\pm$ 0.01 & M8 & 1 \\
# IRS J03443929+3214430 & 03 44 39.28 & +32 14 42.9 & 18.09 $\pm$ 0.05 & 16.58 $\pm$ 0.02 & 15.39 $\pm$ 0.02 & M7.5 & 1 \\
# IRS J03444171+3217549 & 03 44 41.70 & +32 17 54.8 & 17.48 $\pm$ 0.03 & 16.64 $\pm$ 0.02 & 15.81 $\pm$ 0.02 & L0 & 1 \\
# IRS J03444931+3209494 & 03 44 49.33 & +32 09 49.4 & 18.63 $\pm$ 0.09 & 17.67 $\pm$ 0.06 & 16.82 $\pm$ 0.05 & M9.5 & 1 \\
# IRS J03445026+3206357 & 03 44 50.25 & +32 06 35.5 & 18.92 $\pm$ 0.12 & 18.12 $\pm$ 0.09 & 17.35 $\pm$ 0.08 & M9.5 & 1 \\
# IRS J03445053+3156575 & 03 44 50.52 & +31 56 57.2 & 17.97 $\pm$ 0.05 & 17.08 $\pm$ 0.04 & 16.29 $\pm$ 0.03 & L0 & 1 \\
# 2MASS J03445148+3219540 & 03 44 51.48 & +32 19 54.1 & 16.19 $\pm$ 0.01 & 15.39 $\pm$ 0.01 & 14.73 $\pm$ 0.01 & M6.5 & 1 \\
# IRS J03445201+3159219 & 03 44 52.00 & +31 59 21.6 & 17.65 $\pm$ 0.04 & 16.63 $\pm$ 0.03 & 15.78 $\pm$ 0.02 & M9.75 & 1 \\
# 2MASS J03445688+3220355 & 03 44 56.90 & +32 20 35.6 & 18.21 $\pm$ 0.06 & 16.88 $\pm$ 0.03 & 15.14 $\pm$ 0.01 & M6 & 1 \\
# IRS J03445735+3208354 & 03 44 57.34 & +32 08 35.1 & 18.00 $\pm$ 0.05 & 17.10 $\pm$ 0.04 & 16.32 $\pm$ 0.03 & M7.75 & 1 \\
# 2MASS J03445771+3207416 & 03 44 57.72 & +32 07 41.7 & 14.27 $\pm$ 0.01 & 13.63 $\pm$ 0.01 & 13.09 $\pm$ 0.01 & M6.5 & 1 \\
# IRS J03445836+3218118 & 03 44 58.36 & +32 18 11.7 & 16.75 $\pm$ 0.02 & 15.89 $\pm$ 0.02 & 15.20 $\pm$ 0.02 & M6 & 1 \\
# 2MASS J03445853+3158270 & 03 44 58.55 & +31 58 27.0 & 15.60 $\pm$ 0.01 & 14.71 $\pm$ 0.01 & 13.97 $\pm$ 0.01 & M6.5 & 1 \\
# IRS J03450361+3212140 & 03 45 03.62 & +32 12 13.8 & 17.06 $\pm$ 0.03 & 16.36 $\pm$ 0.02 & 15.78 $\pm$ 0.02 & M8.25 & 1 \\
# 2MASS J03450377+3221344 & 03 45 03.78 & +32 21 34.5 & 13.95 $\pm$ 0.01 & 13.32 $\pm$ 0.01 & 12.79 $\pm$ 0.01 & M6.5 & 1 \\
# 2MASS J03450414+3205043 & 03 45 04.13 & +32 05 04.5 & 16.30 $\pm$ 0.02 & 15.44 $\pm$ 0.01 & 14.76 $\pm$ 0.01 & M7 & 1 \\
# IRS J03450417+3206031 & 03 45 04.18 & +32 06 02.9 & 18.22 $\pm$ 0.06 & 17.54 $\pm$ 0.06 & 16.84 $\pm$ 0.05 & M9 & 1 \\
# 2MASS J03450644+3159394 & 03 45 06.45 & +31 59 39.5 & 15.78 $\pm$ 0.01 & 14.79 $\pm$ 0.01 & 14.08 $\pm$ 0.01 & M6.5 & 1 \\
# IRS J03450885+3215471 & 03 45 08.87 & +32 15 46.9 & 18.17 $\pm$ 0.06 & 17.23 $\pm$ 0.04 & 16.36 $\pm$ 0.03 & L0 & 1 \\
# 2MASS J03451212+3209131 & 03 45 12.13 & +32 09 13.1 & 14.09 $\pm$ 0.01 & 13.47 $\pm$ 0.01 & 12.98 $\pm$ 0.01 & M6 & 1 \\
# IRS J03451284+3203362 & 03 45 12.85 & +32 03 36.0 & 17.97 $\pm$ 0.05 & 17.20 $\pm$ 0.04 & 16.48 $\pm$ 0.04 & M9 & 1 \\
# IRS J03451765+3207553 & 03 45 17.65 & +32 07 55.3 & 18.31 $\pm$ 0.07 & 17.31 $\pm$ 0.05 & 16.40 $\pm$ 0.04 & L0 & 1 \\
# 2MASS J03452212+3205450 & 03 45 22.15 & +32 05 45.2 & 17.34 $\pm$ 0.03 & 16.16 $\pm$ 0.02 & 15.22 $\pm$ 0.02 & M8 & 1 \\
# 2MASS J03452390+3211544 & 03 45 23.89 & +32 11 54.5 & 15.32 $\pm$ 0.01 & 14.56 $\pm$ 0.01 & 13.95 $\pm$ 0.01 & M6 & 1 \\
# 2MASS J03453146+3212290 & 03 45 31.44 & +32 12 28.8 & 16.79 $\pm$ 0.02 & 15.94 $\pm$ 0.02 & 15.27 $\pm$ 0.02 & M6.5 & 1 \\
# 2MASS J03454360+3212317 & 03 45 43.60 & +32 12 31.8 & 15.59 $\pm$ 0.01 & 15.04 $\pm$ 0.01 & 14.57 $\pm$ 0.01 & M6.5 & 1 \\
# /Users/tsrice/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
# /Users/tsrice/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
# /Users/tsrice/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior

# %%
coords[0].ra.to_string(sep=':', precision=2, unit=u.hourangle)
# Out:
# '3:43:22.51'

# %%
coords[0].dec.to_string(sep=':', precision=2, alwayssign=True)
# Out:
# '+32:18:17.46'

# %%
Angle.to_string?

# %%
' & '.join(['1', '2', '3']) + '\\'
# Out:
# '1 & 2 & 3\\'
