# %% [markdown]
# # Goal
#
# We want to see if the old code in tile_maps.py (which came originally from wuvars-perseus/preliminary_figures.py) still works. Then we will adapt it.

# %%
# %run ../legacy_tile_maps.py
# Out:
# Auto-detected table type: fits
# Auto-detected table type: fits
# Auto-detected table type: fits
# Auto-detected table type: fits

# %%
fig1 = f_observing_map(fulldata, spread)
fig2 = f_observing_map(fulldata_cleaned, spread_cleaned)

# %%
# %run ../tile_maps.py

# %%
fig1 = f_observing_map(fulldata, spread)

# %%
# %run ../tile_maps_pd.py

# %%
fig1 = f_observing_map()

# %%
plt.hist(w7_spread_clean['variability']['Stetson_JHK'], bins=20)
plt.semilogy()
# Out:
# []
